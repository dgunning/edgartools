# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dgunning/edgartools/blob/main/notebooks/extract-revenue-earnings-python.ipynb)
#
# # Extract Revenue and Earnings from SEC Filings with Python -- Free, No API Key
#
# Use **edgartools** to extract revenue, net income, and other financial metrics from SEC filings in Python -- completely free, no API key or paid subscription required. Pull key numbers from the latest filing, build multi-year revenue histories, or compare financials across companies.
#
# **What you'll learn:**
# - Extract revenue, net income, and other key metrics from any public company
# - Build multi-year revenue and earnings histories
# - Access full income statements, balance sheets, and cash flow statements
# - Compare financials across multiple companies
# - Export financial data to pandas DataFrames

# %% [markdown]
# ## Install edgartools

# %%
# !pip install -U edgartools
# Out:
# Requirement already satisfied: edgartools in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (5.15.3)
# Requirement already satisfied: beautifulsoup4>=4.10.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from edgartools) (4.14.3)
# Requirement already satisfied: httpx>=0.25.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from edgartools) (0.28.1)
# Requirement already satisfied: httpxthrottlecache>=0.3.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from edgartools) (0.3.0)
# Requirement already satisfied: humanize>=4.0.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from edgartools) (4.15.0)
# Requirement already satisfied: jinja2>=3.1.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from edgartools) (3.1.6)
# Requirement already satisfied: lxml>=4.4 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from edgartools) (6.0.2)
# Requirement already satisfied: nest-asyncio>=1.5.1 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from edgartools) (1.6.0)
# Requirement already satisfied: orjson>=3.6.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from edgartools) (3.11.5)
# Requirement already satisfied: pandas>=2.0.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from edgartools) (2.3.3)
# Requirement already satisfied: pyarrow>=17.0.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from edgartools) (22.0.0)
# Requirement already satisfied: pydantic>=2.0.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from edgartools) (2.12.5)
# Requirement already satisfied: pyrate-limiter>=3.0.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from edgartools) (3.9.0)
# Requirement already satisfied: rank-bm25>=0.2.1 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from edgartools) (0.2.2)
# Requirement already satisfied: rapidfuzz>=3.5.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from edgartools) (3.14.3)
# Requirement already satisfied: rich>=13.8.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from edgartools) (14.2.0)
# Requirement already satisfied: stamina>=24.2.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from edgartools) (25.2.0)
# Requirement already satisfied: tabulate>=0.9.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from edgartools) (0.9.0)
# Requirement already satisfied: textdistance>=4.5.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from edgartools) (4.6.3)
# Requirement already satisfied: tqdm>=4.62.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from edgartools) (4.67.1)
# Requirement already satisfied: unidecode>=1.2.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from edgartools) (1.4.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from beautifulsoup4>=4.10.0->edgartools) (2.8.1)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from beautifulsoup4>=4.10.0->edgartools) (4.15.0)
# Requirement already satisfied: anyio in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from httpx>=0.25.0->edgartools) (4.12.1)
# Requirement already satisfied: certifi in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from httpx>=0.25.0->edgartools) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from httpx>=0.25.0->edgartools) (1.0.9)
# Requirement already satisfied: idna in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from httpx>=0.25.0->edgartools) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.25.0->edgartools) (0.16.0)
# Requirement already satisfied: aiofiles>=24.1.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from httpxthrottlecache>=0.3.0->edgartools) (25.1.0)
# Requirement already satisfied: filelock>=3.18.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from httpxthrottlecache>=0.3.0->edgartools) (3.20.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from jinja2>=3.1.0->edgartools) (3.0.3)
# Requirement already satisfied: numpy>=1.23.2 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from pandas>=2.0.0->edgartools) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from pandas>=2.0.0->edgartools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from pandas>=2.0.0->edgartools) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from pandas>=2.0.0->edgartools) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from pydantic>=2.0.0->edgartools) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from pydantic>=2.0.0->edgartools) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from pydantic>=2.0.0->edgartools) (0.4.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from rich>=13.8.0->edgartools) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from rich>=13.8.0->edgartools) (2.19.2)
# Requirement already satisfied: tenacity in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from stamina>=24.2.0->edgartools) (9.1.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->edgartools) (0.1.2)
# Requirement already satisfied: six>=1.5 in /Users/dwight/Library/Application Support/hatch/env/virtual/edgartools/jY6urB4z/edgartools/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->edgartools) (1.17.0)
#
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Setup
#
# The SEC requires all automated tools to identify themselves. Replace the email below with your own -- any valid email works.

# %%
from edgar import *

# The SEC requires you to identify yourself (any email works)
set_identity("your.name@example.com")

# %% [markdown]
# ## Get Revenue in 2 Lines
#
# The fastest way to get a company's revenue from its latest SEC filing:

# %%
financials = Company("NVDA").get_financials()
print(f"Revenue: ${financials.get_revenue():,.0f}")
# Out:
# Revenue: $130,497,000,000

# %% [markdown]
# ## Extract Key Financial Metrics
#
# The `Financials` object has methods for every major metric. No need to parse financial statements yourself:

# %%
fin = Company("NVDA").get_financials()

print(f"Revenue:              ${fin.get_revenue():>20,.0f}")
print(f"Net Income:           ${fin.get_net_income():>20,.0f}")
print(f"Total Assets:         ${fin.get_total_assets():>20,.0f}")
print(f"Total Liabilities:    ${fin.get_total_liabilities():>20,.0f}")
print(f"Stockholders' Equity: ${fin.get_stockholders_equity():>20,.0f}")
print(f"Free Cash Flow:       ${fin.get_free_cash_flow():>20,.0f}")
print(f"Operating Cash Flow:  ${fin.get_operating_cash_flow():>20,.0f}")
print(f"CapEx:                ${fin.get_capital_expenditures():>20,.0f}")
# Out:
# Revenue:              $     130,497,000,000
# Net Income:           $      72,880,000,000
# Total Assets:         $     111,601,000,000
# Total Liabilities:    $      32,274,000,000
# Stockholders' Equity: $      79,327,000,000
# Free Cash Flow:       $      63,960,000,000
# Operating Cash Flow:  $      64,089,000,000
# CapEx:                $         129,000,000

# %% [markdown]
# Or get everything at once as a dictionary:

# %%
metrics = fin.get_financial_metrics()
metrics
# Out:
# {'revenue': 130497000000.0,
#  'net_income': 72880000000.0,
#  'total_assets': 111601000000.0,
#  'total_liabilities': 32274000000.0,
#  'stockholders_equity': 79327000000.0,
#  'current_assets': 80126000000.0,
#  'current_liabilities': 18047000000.0,
#  'operating_cash_flow': 64089000000.0,
#  'capital_expenditures': 129000000.0,
#  'free_cash_flow': 63960000000.0,
#  'shares_outstanding_basic': 24555000000.0,
#  'shares_outstanding_diluted': 24804000000.0,
#  'current_ratio': 4.439851498864077,
#  'debt_to_assets': 0.28919095707027714}

# %% [markdown]
# ## View the Full Income Statement
#
# For complete detail beyond individual metrics, access the full income statement. This shows revenue, expenses, and earnings with multi-year comparisons:

# %%
fin.income_statement()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#
#                                         NVIDIA CORP   NVDA
#                                         CONSOLIDATED STATEMENT OF INCOME
#                                         Jan 29, 2023 to Jan 26, 2025
#
#                                                                   Jan 26, 2025   Jan 28, 2024   Jan 29, 2023
#    ──────────────────────────────────────────────────────────────────────────────────────────────────────────
#         Revenue:                                                      $130,497        $60,922        $26,974
#         Data Center                                                   $115,186        $47,525        $15,005
#         Compute                                                       $102,196        $38,950        $11,317
#         Networking                                                     $12,990         $8,575         $3,688
#         Gaming                                                         $11,350        $10,447         $9,067
#         Professional Visualization                                      $1,878         $1,553         $1,544
#         Automotive                                                      $1,694         $1,091           $903
#         OEM and Other                                                     $389           $306           $455
#         Cost of revenue:                                               $32,639        $16,621        $11,618
#         Inventory purchase obligations in excess of projections         $2,000         $1,400
#       Gross profit                                                     $97,858        $44,301        $15,356
#     Operating expenses
#           Research and development                                     $12,914         $8,675         $7,339
#           Sales, general and administrative                             $3,491         $2,654         $2,440
#           Acquisition termination cost                                                                $1,353
#           Total operating expenses                                     $16,405        $11,329        $11,132
#         Operating income:                                              $81,453        $32,972         $4,224
#         Interest income                                                 $1,786           $866           $267
#         Interest expense                                                $(247)         $(257)         $(262)
#         Other, net                                                      $1,034           $237          $(48)
#         Other income (expense), net                                     $2,573           $846          $(43)
#       Income before income tax                                         $84,026        $33,818         $4,181
#       Income tax expense (benefit)                                     $11,146         $4,058         $(187)
#       Net income:                                                      $72,880        $29,760         $4,368
#     Net income per share:
#         Basic (in USD per share)                                          2.97           1.21           0.18
#         Diluted (in USD per share)                                        2.94           1.19           0.17
#     Weighted average shares used in per share computation:
#         Basic (in shares)                                               24,555         24,690         24,870
#         Diluted (in shares)                                             24,804         24,940         25,070
#
#    Source: SEC XBRL  •  (In millions, except shares and per share data)

# %% [markdown]
# Balance sheet and cash flow statements are available too:

# %%
fin.balance_sheet()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#
#                                            NVIDIA CORP   NVDA
#                                            CONSOLIDATED BALANCE SHEETS
#                                            Jan 28, 2024 to Jan 26, 2025
#
#                                                                                     Jan 26, 2025   Jan 28, 2024
#    ─────────────────────────────────────────────────────────────────────────────────────────────────────────────
#     Assets
#       Current assets:
#             Cash and cash equivalents                                                     $8,589         $7,280
#             Marketable securities                                                        $34,621        $18,704
#             Accounts receivable, net                                                     $23,065         $9,999
#             Inventories                                                                  $10,080         $5,282
#             Prepaid expenses and other current assets:                                    $3,771         $3,080
#             Supply and Capacity Agreements                                                $3,300         $2,500
#           Total current assets                                                           $80,126        $44,345
#           Property and equipment, net                                                     $6,283         $3,914
#           Operating lease assets                                                          $1,793         $1,346
#           Goodwill:                                                                       $5,188         $4,430
#           Intangible assets, net                                                            $807         $1,112
#           Deferred income tax assets                                                     $10,979         $6,081
#           Other assets                                                                    $6,425         $4,500
#         Total assets                                                                    $111,601        $65,728
#     Liabilities and Shareholders' Equity
#       Current liabilities:
#             Accounts payable                                                              $6,310         $2,699
#             Accrued and other current liabilities                                        $11,737         $6,682
#             Short-term debt                                                                              $1,250
#           Total current liabilities                                                      $18,047        $10,631
#           Long-term debt                                                                  $8,463         $8,459
#           Long-term operating lease liabilities                                           $1,519         $1,119
#           Other long-term liabilities                                                     $4,245         $2,541
#           Total liabilities                                                              $32,274        $22,750
#           Commitments and contingencies - see Note 12
#       Shareholders’ equity:
#           Preferred stock, $0.001 par value; 20 shares authorized; none issued
#           Common stock, $0.001 par value; 80,000 shares authorized; 24,477 shares            $24            $25
#     issued and outstanding as of January 26, 2025; 24,643 shares issued and
#     outstanding as of January 28, 2024
#           Additional paid-in capital                                                     $11,237        $13,109
#           Accumulated other comprehensive income                                             $28            $27
#           Retained earnings                                                              $68,038        $29,817
#           Total shareholders' equity:                                                    $79,327        $42,978
#         Total liabilities and shareholders' equity                                      $111,601        $65,728
#
#    Source: SEC XBRL  •  (In millions, except shares and per share data)

# %%
fin.cashflow_statement()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#
#                                        NVIDIA CORP   NVDA
#                                        CONSOLIDATED STATEMENT OF CASH FLOWS
#                                        Jan 29, 2023 to Jan 26, 2025
#
#                                                                      Jan 26, 2025   Jan 28, 2024   Jan 29, 2023
#    ─────────────────────────────────────────────────────────────────────────────────────────────────────────────
#     Cash flows from operating activities:
#         Net income:                                                       $72,880        $29,760         $4,368
#       Adjustments to reconcile net income to net cash provided by
#     operating activities:
#           Stock-based compensation expense:                                $4,737         $3,549         $2,709
#           Depreciation and amortization:                                   $1,864         $1,508         $1,544
#           Deferred income taxes                                          $(4,477)       $(2,489)       $(2,164)
#           (Gains) losses on non-marketable equity securities and         $(1,030)         $(238)            $45
#     publicly-held equity securities, net
#           Acquisition termination cost                                                                   $1,353
#           Other                                                            $(502)         $(278)           $(7)
#         Changes in operating assets and liabilities, net of
#     acquisitions:
#             Accounts receivable                                         $(13,063)       $(6,172)           $822
#             Inventories                                                  $(4,781)          $(98)       $(2,554)
#             Prepaid expenses and other assets                              $(395)       $(1,522)       $(1,517)
#             Accounts payable                                               $3,357         $1,531         $(551)
#             Accrued and other current liabilities                          $4,278         $2,025         $1,341
#             Other long-term liabilities                                    $1,221           $514           $252
#         Net cash provided by operating activities                         $64,089        $28,090         $5,641
#     Cash flows from investing activities:
#           Proceeds from maturities of marketable securities               $11,195         $9,732        $19,425
#           Proceeds from sales of marketable securities                       $495            $50         $1,806
#           Proceeds from sales of non-marketable equity securities            $171             $1             $8
#           Purchases of marketable securities                            $(26,575)      $(18,211)      $(11,897)
#           Purchases related to property and equipment and                $(3,236)       $(1,069)       $(1,833)
#     intangible assets
#           Purchases of non-marketable equity securities                  $(1,486)         $(862)          $(85)
#           Acquisitions, net of cash acquired                             $(1,007)          $(83)          $(49)
#           Other                                                               $22         $(124)
#         Net cash provided by (used in) investing activities             $(20,421)      $(10,566)         $7,375
#     Cash flows from financing activities:
#           Proceeds related to employee stock plans                           $490           $403           $355
#           Payments related to repurchases of common stock               $(33,706)       $(9,533)      $(10,039)
#           Payments related to tax on restricted stock units              $(6,930)       $(2,783)       $(1,475)
#           Repayment of debt                                              $(1,250)       $(1,250)
#           Dividends paid                                                   $(834)         $(395)         $(398)
#           Principal payments on property and equipment and                 $(129)          $(74)          $(58)
#     intangible assets
#           Other                                                                             $(1)           $(2)
#         Net cash used in financing activities                           $(42,359)      $(13,633)      $(11,617)
#       Change in cash and cash equivalents                                  $1,309         $3,891         $1,399
#       Cash and cash equivalents at end of period
#       Cash and cash equivalents at end of period
#     Supplemental disclosures of cash flow information:
#         Cash paid for income taxes, net                                   $15,118         $6,549         $1,404
#         Cash paid for interest                                               $246           $252           $254
#
#    Source: SEC XBRL  •  (In millions, except shares and per share data)

# %% [markdown]
# ## Export to a pandas DataFrame
#
# Convert any financial statement to a DataFrame for custom analysis:

# %%
df = fin.income_statement().to_dataframe()
df.head(10)
# Out:
#             concept                                      label  \
# 0  us-gaap_Revenues                                    Revenue
# 1  us-gaap_Revenues  Operating segments - Compute & Networking
# 2  us-gaap_Revenues              Operating segments - Graphics
# 3  us-gaap_Revenues                                  All Other
# 4  us-gaap_Revenues                              United States
# 5  us-gaap_Revenues                                  Singapore
# 6  us-gaap_Revenues                                     Taiwan
# 7  us-gaap_Revenues                China (including Hong Kong)
# 8  us-gaap_Revenues                                      Other
# 9  us-gaap_Revenues                                Data Center
#
#   standard_concept    2025-01-26    2024-01-28    2023-01-29  level  abstract  \
# 0          Revenue  1.304970e+11  6.092200e+10  2.697400e+10      2     False
# 1             None  1.161930e+11  4.740500e+10  1.506800e+10      2     False
# 2             None  1.430400e+10  1.351700e+10  1.190600e+10      2     False
# 3             None  0.000000e+00  0.000000e+00  0.000000e+00      2     False
# 4             None  6.125700e+10  2.696600e+10  8.292000e+09      2     False
# 5             None  2.368400e+10  6.831000e+09  2.288000e+09      2     False
# 6             None  2.057300e+10  1.340500e+10  6.986000e+09      2     False
# 7             None  1.710800e+10  1.030600e+10  5.785000e+09      2     False
# 8             None  7.875000e+09  3.414000e+09  3.623000e+09      2     False
# 9             None  1.151860e+11  4.752500e+10  1.500500e+10      2     False
#
#    dimension  is_breakdown                 dimension_axis  \
# 0      False         False                           None
# 1       True          True     srt:ConsolidationItemsAxis
# 2       True          True     srt:ConsolidationItemsAxis
# 3       True          True     srt:ConsolidationItemsAxis
# 4       True          True  srt:StatementGeographicalAxis
# 5       True          True  srt:StatementGeographicalAxis
# 6       True          True  srt:StatementGeographicalAxis
# 7       True          True  srt:StatementGeographicalAxis
# 8       True          True  srt:StatementGeographicalAxis
# 9       True         False       srt:ProductOrServiceAxis
#
#                     dimension_member       dimension_member_label  \
# 0                               None                         None
# 1    us-gaap_OperatingSegmentsMember           Operating segments
# 2    us-gaap_OperatingSegmentsMember           Operating segments
# 3  us-gaap_CorporateNonSegmentMember                    All Other
# 4                         country_US                United States
# 5                         country_SG                    Singapore
# 6                         country_TW                       Taiwan
# 7  nvda_ChinaIncludingHongKongMember  China (including Hong Kong)
# 8          nvda_OtherCountriesMember                        Other
# 9              nvda_DataCenterMember                  Data Center
#
#                                      dimension_label balance  weight  \
# 0                                               None  credit     1.0
# 1  srt:ConsolidationItemsAxis: Operating segments...  credit     1.0
# 2  srt:ConsolidationItemsAxis: Operating segments...  credit     1.0
# 3              srt:ConsolidationItemsAxis: All Other  credit     1.0
# 4       srt:StatementGeographicalAxis: United States  credit     1.0
# 5           srt:StatementGeographicalAxis: Singapore  credit     1.0
# 6              srt:StatementGeographicalAxis: Taiwan  credit     1.0
# 7  srt:StatementGeographicalAxis: China (includin...  credit     1.0
# 8               srt:StatementGeographicalAxis: Other  credit     1.0
# 9              srt:ProductOrServiceAxis: Data Center  credit     1.0
#
#    preferred_sign       parent_concept          parent_abstract_concept
# 0             1.0  us-gaap_GrossProfit  us-gaap_IncomeStatementAbstract
# 1             1.0  us-gaap_GrossProfit  us-gaap_IncomeStatementAbstract
# 2             1.0  us-gaap_GrossProfit  us-gaap_IncomeStatementAbstract
# 3             1.0  us-gaap_GrossProfit  us-gaap_IncomeStatementAbstract
# 4             1.0  us-gaap_GrossProfit  us-gaap_IncomeStatementAbstract
# 5             1.0  us-gaap_GrossProfit  us-gaap_IncomeStatementAbstract
# 6             1.0  us-gaap_GrossProfit  us-gaap_IncomeStatementAbstract
# 7             1.0  us-gaap_GrossProfit  us-gaap_IncomeStatementAbstract
# 8             1.0  us-gaap_GrossProfit  us-gaap_IncomeStatementAbstract
# 9             1.0  us-gaap_GrossProfit  us-gaap_IncomeStatementAbstract

# %% [markdown]
# ## Build a Multi-Year Revenue History
#
# SEC EDGAR stores every fact a company has ever reported. Use `get_facts()` to access the full history and `time_series()` to track any concept over time:

# %%
facts = Company("NVDA").get_facts()

# Get annual revenue history
revenue_ts = facts.time_series("Revenues")
annual_revenue = revenue_ts[revenue_ts["fiscal_period"] == "FY"].sort_values("period_end")

for _, row in annual_revenue.iterrows():
    print(f"  {row['period_end']}   ${row['numeric_value']:>20,.0f}")
# Out:
#   2023-01-29   $      26,974,000,000
#   2024-01-28   $      60,922,000,000
#   2025-01-26   $     130,497,000,000

# %% [markdown]
# ## Look Up Revenue for a Specific Fiscal Year
#
# Use `get_annual_fact()` to pull a specific year's value directly:

# %%
rev_2025 = facts.get_annual_fact("Revenues", fiscal_year=2025)
print(f"FY 2025 Revenue: ${rev_2025.value:>20,}")
print(f"Period ending:   {rev_2025.period_end}")
print(f"XBRL concept:    {rev_2025.concept}")
# Out:
# FY 2025 Revenue: $     130,497,000,000
# Period ending:   2025-01-26
# XBRL concept:    us-gaap:Revenues

# %% [markdown]
# ## Track Multiple Metrics Over Time
#
# Combine multiple time series into a single DataFrame to see how revenue, earnings, and EPS have changed together:

# %%
import pandas as pd

# Build a multi-metric annual history
rev = facts.time_series("Revenues")
ni = facts.time_series("NetIncomeLoss")
eps = facts.time_series("EarningsPerShareDiluted")

# Filter to annual and merge
rev_annual = rev[rev["fiscal_period"] == "FY"][["period_end", "numeric_value"]].rename(columns={"numeric_value": "Revenue"})
ni_annual = ni[ni["fiscal_period"] == "FY"][["period_end", "numeric_value"]].rename(columns={"numeric_value": "Net Income"})
eps_annual = eps[eps["fiscal_period"] == "FY"][["period_end", "numeric_value"]].rename(columns={"numeric_value": "EPS (Diluted)"})

history = rev_annual.merge(ni_annual, on="period_end").merge(eps_annual, on="period_end").sort_values("period_end")
history
# Out:
#    period_end       Revenue    Net Income  EPS (Diluted)
# 0  2023-01-29  2.697400e+10  4.368000e+09           0.17
# 1  2024-01-28  6.092200e+10  2.976000e+10           1.19
# 2  2025-01-26  1.304970e+11  7.288000e+10           2.94

# %% [markdown]
# ## Multi-Year Financial Statements
#
# The `get_facts()` approach also provides complete multi-year financial statements, automatically spanning all years the company has reported:

# %%
facts.income_statement()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#
#                                    NVIDIA CORP   NVDA
#                                    INCOME STATEMENT
#                                    FY 2022 to FY 2025
#
#                                         FY 2025      FY 2024      FY 2023      FY 2022
#    ────────────────────────────────────────────────────────────────────────────────────
#     Total Revenue                       $130.5B       $60.9B       $27.0B       $26.9B
#     Cost of Revenue                      $32.6B       $16.6B       $11.6B        $9.4B
#     Gross Profit                         $97.9B       $44.3B       $15.4B       $17.5B
#     Operating expenses:
#       Research and Development           $12.9B        $8.7B        $7.3B        $5.3B
#     Expense
#       Operating Expenses                 $16.4B       $11.3B       $11.1B        $7.4B
#     Selling, General and                  $3.5B        $2.7B        $2.4B        $2.2B
#     Administrative Expense ◦
#     Operating Income (Loss)              $81.5B       $33.0B        $4.2B       $10.0B
#     Other Nonoperating Income             $1.0B      $237.0M      $-48.0M      $107.0M
#     (Expense) ◦
#     Income (Loss) from Continuing        $84.0B       $33.8B        $4.2B        $9.9B
#     Operations before Income
#     Taxes, Noncontrolling Interest
#     Income Tax Expense (Benefit)         $11.1B        $4.1B     $-187.0M      $189.0M
#     Net Income (Loss) Attributable       $72.9B       $29.8B        $4.4B        $9.8B
#     to Parent
#     Earnings Per Share, Basic              2.97        12.05         1.76         3.91
#     Earnings Per Share, Diluted            2.94        11.93         1.74         3.85
#     Additional Financial Items
#       Amortization of Intangible        $593.0M      $614.0M      $699.0M      $563.0M
#     Assets ◦
#       Common Stock, Dividends, Per         0.03         0.16         0.16
#     Share, Declared ◦
#       Current Income Tax Expense         $15.6B        $6.5B        $2.0B      $595.0M
#     (Benefit) ◦
#       Gain (Loss) on Investments ◦        $1.0B      $238.0M      $-45.0M      $100.0M
#       Goodwill, Impairment Loss ◦            $0           $0           $0           $0
#       Income (Loss) from                 $77.5B       $29.5B        $3.5B        $8.4B
#     Continuing Operations before
#     Income Taxes, Domestic ◦
#       Interest Expense ◦                             $257.0M      $262.0M      $236.0M
#
#    Source: EntityFacts  •  Amounts in USD

# %% [markdown]
# ## Compare Revenue Across Companies
#
# Pull the same metric from multiple companies to build a comparison:

# %%
tickers = ["NVDA", "MSFT", "AAPL", "GOOG"]

print(f"{'Company':<10} {'Revenue':>20} {'Net Income':>20} {'Total Assets':>20}")
print("-" * 74)

for ticker in tickers:
    fin = Company(ticker).get_financials()
    print(f"{ticker:<10} ${fin.get_revenue():>19,.0f} ${fin.get_net_income():>19,.0f} ${fin.get_total_assets():>19,.0f}")
# Out:
# Company                 Revenue           Net Income         Total Assets
# --------------------------------------------------------------------------
# NVDA       $    130,497,000,000 $     72,880,000,000 $    111,601,000,000
# MSFT       $    281,724,000,000 $    101,832,000,000 $    619,003,000,000
# AAPL       $    416,161,000,000 $    112,010,000,000 $    359,241,000,000
# GOOG       $    402,836,000,000 $    132,170,000,000 $    595,281,000,000

# %% [markdown]
# ## Discover Available Concepts
#
# Not sure what data is available? List all supported financial concepts, or search for concepts related to a keyword:

# %%
# List all supported high-level concepts
print("Supported concepts:")
print(facts.list_supported_concepts())
# Out:
# Supported concepts:
# ['accounts_payable', 'accounts_receivable', 'accrued_liabilities', 'accumulated_other_comprehensive_income', 'additional_paid_in_capital', 'book_value_per_share', 'capex', 'cash_and_equivalents', 'common_shares_outstanding', 'common_stock', 'cost_of_revenue', 'debt_proceeds', 'debt_repayment', 'deferred_revenue', 'deferred_tax_assets', 'deferred_tax_liabilities', 'depreciation_and_amortization', 'dividends_paid', 'earnings_per_share_basic', 'earnings_per_share_diluted', 'ebitda', 'finance_lease_liability', 'financing_cash_flow', 'free_cash_flow', 'goodwill', 'gross_profit', 'income_before_tax', 'income_tax_expense', 'intangible_assets', 'interest_expense', 'interest_income', 'inventory', 'investing_cash_flow', 'long_term_debt', 'long_term_investments', 'net_income', 'operating_cash_flow', 'operating_expenses', 'operating_income', 'operating_lease_liability', 'operating_lease_payments', 'operating_lease_right_of_use_asset', 'prepaid_expenses', 'property_plant_equipment', 'research_and_development', 'retained_earnings', 'return_on_assets', 'return_on_equity', 'revenue', 'sga_expense', 'share_repurchases', 'short_term_debt', 'short_term_investments', 'stockholders_equity', 'total_assets', 'total_current_assets', 'total_current_liabilities', 'total_liabilities', 'treasury_stock']

# %%
# Find the exact XBRL tags a company uses for "Revenue"
facts.discover_concept_tags("Revenue")
# Out:
# ['RevenueFromContractWithCustomerExcludingAssessedTax', 'Revenues']

# %% [markdown]
# ## Why EdgarTools?
#
# EdgarTools is free and open-source. Compare extracting revenue and earnings:
#
# **With edgartools (free, no API key):**
# ```python
# fin = Company("NVDA").get_financials()
# print(fin.get_revenue())       # Latest revenue
# print(fin.get_net_income())    # Latest net income
# ```
#
# **Typical paid API approach ($50+/month, API key required):**
# ```python
# from sec_api import XbrlApi
# api = XbrlApi(api_key="YOUR_PAID_API_KEY")
# data = api.xbrl_to_json(htm_url=filing_url)
# # ... then traverse nested JSON to find revenue among hundreds of XBRL facts
# ```
#
# With edgartools, financial metrics are extracted into named Python methods -- no JSON traversal, no API key, no monthly fee.

# %% [markdown]
# ## Quick Reference
#
# ```python
# from edgar import *
# set_identity("your.name@example.com")
#
# # ── Quick extraction from latest filing ──
# fin = Company("NVDA").get_financials()
# fin.get_revenue()                  # Revenue
# fin.get_net_income()               # Net income
# fin.get_total_assets()             # Total assets
# fin.get_free_cash_flow()           # Free cash flow
# fin.get_financial_metrics()        # All metrics as dict
#
# # Financial statements
# fin.income_statement()             # Full income statement
# fin.balance_sheet()                # Balance sheet
# fin.cashflow_statement()           # Cash flow statement
#
# # Export to pandas
# df = fin.income_statement().to_dataframe()
#
# # ── Multi-year history from all filings ──
# facts = Company("NVDA").get_facts()
# facts.get_revenue()                # Latest revenue
# facts.time_series("Revenues")      # Revenue over time (DataFrame)
# facts.get_annual_fact("Revenues", fiscal_year=2024)  # Specific year
# facts.income_statement()           # Multi-year income statement
# facts.list_supported_concepts()    # Available concepts
# ```

# %% [markdown]
# ## What's Next
#
# You've learned how to extract revenue and earnings from SEC filings with Python. Here are related tutorials:
#
# - [Download and Parse 10-K Annual Reports](https://colab.research.google.com/github/dgunning/edgartools/blob/main/notebooks/download-10k-annual-report-python.ipynb)
# - [Parse XBRL Financial Data from SEC EDGAR](https://colab.research.google.com/github/dgunning/edgartools/blob/main/notebooks/Reading-Data-From-XBRL.ipynb)
# - [Extract Financial Statements from SEC Filings](https://colab.research.google.com/github/dgunning/edgartools/blob/main/notebooks/Viewing-Financial-Statements.ipynb)
# - [Search SEC Filings with Python](https://colab.research.google.com/github/dgunning/edgartools/blob/main/notebooks/01_getting_started.ipynb)
#
# **Resources:**
# - [EdgarTools Documentation](https://edgartools.readthedocs.io/)
# - [GitHub Repository](https://github.com/dgunning/edgartools)
# - [PyPI Package](https://pypi.org/project/edgartools/)

# %% [markdown]
# ---
#
# ## Support EdgarTools
#
# If you found this tutorial helpful, here are a few ways to support the project:
#
# - **Star the repo** -- [github.com/dgunning/edgartools](https://github.com/dgunning/edgartools) -- it helps others discover edgartools
# - **Visit edgartools.io** -- [edgartools.io](https://www.edgartools.io/) -- for more tutorials, articles, and updates
# - **Report issues** -- found a bug or have a feature idea? [Open an issue](https://github.com/dgunning/edgartools/issues)
# - **Share this notebook** -- know someone who works with SEC data? Send them the Colab link
#
# *edgartools is free, open-source, and community-driven. No API key or paid subscription required.*
