# %% [markdown]
# # Financial Ratios

# %%
from edgar import *
from edgar.xbrl import *

# %%
c = Company("AAPL")
filing = c.latest("10-K")
xbrl = XBRL.from_filing(filing)

# %%
cash_flow = xbrl.statements.cash_flow_statement()
cash_flow
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                 Consolidated Statement of Cash Flows (Standardized)
#                                   Year Ended (In millions, except per share data)
#
#                                                Annual: Sep 28, 2024   Annual: Sep 30, 2023   Annual: Sep 24, 2022
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#     Cash, cash equivalents, and restricted
#   cash and cash equivalents, ending balances
#     Operating activities:
#       Net Income                                            $93,736                $96,995                $99,803
#       Adjustments to reconcile net income to
#   cash generated by operating activities:
#         Depreciation and amortization                       $11,445                $11,519                $11,104
#         Share-based compensation expense                    $11,688                $10,833                 $9,038
#         Other                                              $(2,266)               $(2,227)                 $1,006
#         Changes in operating assets and
#   liabilities:
#           Accounts receivable, net                         $(3,788)               $(1,688)               $(1,823)
#           Vendor non-trade receivables                     $(1,356)                 $1,271               $(7,520)
#           Inventories                                      $(1,046)               $(1,618)                 $1,484
#           Other current and non-current                   $(11,731)               $(5,684)               $(6,499)
#   assets
#           Accounts Payable                                   $6,020               $(1,889)                 $9,448
#           Other current and non-current                     $15,552                 $3,031                 $6,110
#   liabilities
#       Net Cash from Operating Activities                   $118,254               $110,543               $122,151
#     Investing activities:
#       Purchases of marketable securities                  $(48,656)              $(29,513)              $(76,923)
#       Proceeds from Maturities, Prepayments                 $51,211                $39,686                $29,917
#   and Calls of Securities
#       Proceeds from Sale of Debt Securities,                $11,135                 $5,828                $37,446
#       Payments for Property, Plant and                     $(9,447)              $(10,959)              $(10,708)
#   Equipment
#       Other                                                $(1,308)               $(1,337)               $(2,086)
#       Net Cash from Investing Activities                     $2,935                 $3,705              $(22,354)
#     Financing activities:
#       Tax Withholding for Share-Based                      $(5,441)               $(5,431)               $(6,223)
#   Compensation
#       Payments of Dividends                               $(15,234)              $(15,025)              $(14,841)
#       Repurchases of common stock                         $(94,949)              $(77,550)              $(89,402)
#       Proceeds from Issuance of Long-Term                                           $5,228                 $5,465
#   Debt
#       Repayments of term debt                              $(9,958)              $(11,151)               $(9,543)
#       Proceeds from (Repayments of)                          $3,960               $(3,978)                 $3,955
#   Commercial Paper
#       Other                                                  $(361)                 $(581)                 $(160)
#       Net Cash from Financing Activities                 $(121,983)             $(108,488)             $(110,749)
#     Net Change in Cash                                       $(794)                 $5,760              $(10,952)
#     Cash, cash equivalents, and restricted
#   cash and cash equivalents, ending balances
#     Supplemental cash flow disclosure:
#       Income Tax Expense                                    $26,102                $18,679                $19,573

# %%
rendered = cash_flow.render()
rendered.to_dataframe()
# Out:
#                                               concept  \
# 0   us-gaap_CashCashEquivalentsRestrictedCashAndRe...
# 1   us-gaap_NetCashProvidedByUsedInOperatingActivi...
# 2                               us-gaap_NetIncomeLoss
# 3   us-gaap_AdjustmentsToReconcileNetIncomeLossToC...
# 4        us-gaap_DepreciationDepletionAndAmortization
# 5                      us-gaap_ShareBasedCompensation
# 6                   us-gaap_OtherNoncashIncomeExpense
# 7   us-gaap_IncreaseDecreaseInOperatingCapitalAbst...
# 8        us-gaap_IncreaseDecreaseInAccountsReceivable
# 9          us-gaap_IncreaseDecreaseInOtherReceivables
# 10              us-gaap_IncreaseDecreaseInInventories
# 11     us-gaap_IncreaseDecreaseInOtherOperatingAssets
# 12          us-gaap_IncreaseDecreaseInAccountsPayable
# 13  us-gaap_IncreaseDecreaseInOtherOperatingLiabil...
# 14  us-gaap_NetCashProvidedByUsedInOperatingActivi...
# 15  us-gaap_NetCashProvidedByUsedInInvestingActivi...
# 16  us-gaap_PaymentsToAcquireAvailableForSaleSecur...
# 17  us-gaap_ProceedsFromMaturitiesPrepaymentsAndCa...
# 18  us-gaap_ProceedsFromSaleOfAvailableForSaleSecu...
# 19  us-gaap_PaymentsToAcquirePropertyPlantAndEquip...
# 20  us-gaap_PaymentsForProceedsFromOtherInvestingA...
# 21  us-gaap_NetCashProvidedByUsedInInvestingActivi...
# 22  us-gaap_NetCashProvidedByUsedInFinancingActivi...
# 23  us-gaap_PaymentsRelatedToTaxWithholdingForShar...
# 24                        us-gaap_PaymentsOfDividends
# 25         us-gaap_PaymentsForRepurchaseOfCommonStock
# 26         us-gaap_ProceedsFromIssuanceOfLongTermDebt
# 27                   us-gaap_RepaymentsOfLongTermDebt
# 28    us-gaap_ProceedsFromRepaymentsOfCommercialPaper
# 29  us-gaap_ProceedsFromPaymentsForOtherFinancingA...
# 30  us-gaap_NetCashProvidedByUsedInFinancingActivi...
# 31  us-gaap_CashCashEquivalentsRestrictedCashAndRe...
# 32  us-gaap_CashCashEquivalentsRestrictedCashAndRe...
# 33    us-gaap_SupplementalCashFlowInformationAbstract
# 34                         us-gaap_IncomeTaxesPaidNet
#
#                                                 label  2024-09-28  2023-09-30  \
# 0   Cash, cash equivalents, and restricted cash an...
# 1                               Operating activities:
# 2                                          Net Income     $93,736     $96,995
# 3   Adjustments to reconcile net income to cash ge...
# 4                       Depreciation and amortization     $11,445     $11,519
# 5                    Share-based compensation expense     $11,688     $10,833
# 6                                               Other    $(2,266)    $(2,227)
# 7        Changes in operating assets and liabilities:
# 8                            Accounts receivable, net    $(3,788)    $(1,688)
# 9                        Vendor non-trade receivables    $(1,356)      $1,271
# 10                                        Inventories    $(1,046)    $(1,618)
# 11               Other current and non-current assets   $(11,731)    $(5,684)
# 12                                   Accounts Payable      $6,020    $(1,889)
# 13          Other current and non-current liabilities     $15,552      $3,031
# 14                 Net Cash from Operating Activities    $118,254    $110,543
# 15                              Investing activities:
# 16                 Purchases of marketable securities   $(48,656)   $(29,513)
# 17  Proceeds from Maturities, Prepayments and Call...     $51,211     $39,686
# 18            Proceeds from Sale of Debt Securities,      $11,135      $5,828
# 19         Payments for Property, Plant and Equipment    $(9,447)   $(10,959)
# 20                                              Other    $(1,308)    $(1,337)
# 21                 Net Cash from Investing Activities      $2,935      $3,705
# 22                              Financing activities:
# 23       Tax Withholding for Share-Based Compensation    $(5,441)    $(5,431)
# 24                              Payments of Dividends   $(15,234)   $(15,025)
# 25                        Repurchases of common stock   $(94,949)   $(77,550)
# 26           Proceeds from Issuance of Long-Term Debt                 $5,228
# 27                            Repayments of term debt    $(9,958)   $(11,151)
# 28     Proceeds from (Repayments of) Commercial Paper      $3,960    $(3,978)
# 29                                              Other      $(361)      $(581)
# 30                 Net Cash from Financing Activities  $(121,983)  $(108,488)
# 31                                 Net Change in Cash      $(794)      $5,760
# 32  Cash, cash equivalents, and restricted cash an...
# 33                 Supplemental cash flow disclosure:
# 34                                 Income Tax Expense     $26,102     $18,679
#
#     2022-09-24  level  abstract  dimension
# 0                   1     False      False
# 1                   1     False      False
# 2      $99,803      2     False      False
# 3                   2     False      False
# 4      $11,104      3     False      False
# 5       $9,038      3     False      False
# 6       $1,006      3     False      False
# 7                   3     False      False
# 8     $(1,823)      4     False      False
# 9     $(7,520)      4     False      False
# 10      $1,484      4     False      False
# 11    $(6,499)      4     False      False
# 12      $9,448      4     False      False
# 13      $6,110      4     False      False
# 14    $122,151      2     False      False
# 15                  1     False      False
# 16   $(76,923)      2     False      False
# 17     $29,917      2     False      False
# 18     $37,446      2     False      False
# 19   $(10,708)      2     False      False
# 20    $(2,086)      2     False      False
# 21   $(22,354)      2     False      False
# 22                  1     False      False
# 23    $(6,223)      2     False      False
# 24   $(14,841)      2     False      False
# 25   $(89,402)      2     False      False
# 26      $5,465      2     False      False
# 27    $(9,543)      2     False      False
# 28      $3,955      2     False      False
# 29      $(160)      2     False      False
# 30  $(110,749)      2     False      False
# 31   $(10,952)      1     False      False
# 32                  1     False      False
# 33                  1     False      False
# 34     $19,573      2     False      False

# %%
cash_flow.to_dataframe()
# Out:
#                                               concept  \
# 0   us-gaap_CashCashEquivalentsRestrictedCashAndRe...
# 1   us-gaap_NetCashProvidedByUsedInOperatingActivi...
# 2                               us-gaap_NetIncomeLoss
# 3   us-gaap_AdjustmentsToReconcileNetIncomeLossToC...
# 4        us-gaap_DepreciationDepletionAndAmortization
# 5                      us-gaap_ShareBasedCompensation
# 6                   us-gaap_OtherNoncashIncomeExpense
# 7   us-gaap_IncreaseDecreaseInOperatingCapitalAbst...
# 8        us-gaap_IncreaseDecreaseInAccountsReceivable
# 9          us-gaap_IncreaseDecreaseInOtherReceivables
# 10              us-gaap_IncreaseDecreaseInInventories
# 11     us-gaap_IncreaseDecreaseInOtherOperatingAssets
# 12          us-gaap_IncreaseDecreaseInAccountsPayable
# 13  us-gaap_IncreaseDecreaseInOtherOperatingLiabil...
# 14  us-gaap_NetCashProvidedByUsedInOperatingActivi...
# 15  us-gaap_NetCashProvidedByUsedInInvestingActivi...
# 16  us-gaap_PaymentsToAcquireAvailableForSaleSecur...
# 17  us-gaap_ProceedsFromMaturitiesPrepaymentsAndCa...
# 18  us-gaap_ProceedsFromSaleOfAvailableForSaleSecu...
# 19  us-gaap_PaymentsToAcquirePropertyPlantAndEquip...
# 20  us-gaap_PaymentsForProceedsFromOtherInvestingA...
# 21  us-gaap_NetCashProvidedByUsedInInvestingActivi...
# 22  us-gaap_NetCashProvidedByUsedInFinancingActivi...
# 23  us-gaap_PaymentsRelatedToTaxWithholdingForShar...
# 24                        us-gaap_PaymentsOfDividends
# 25         us-gaap_PaymentsForRepurchaseOfCommonStock
# 26         us-gaap_ProceedsFromIssuanceOfLongTermDebt
# 27                   us-gaap_RepaymentsOfLongTermDebt
# 28    us-gaap_ProceedsFromRepaymentsOfCommercialPaper
# 29  us-gaap_ProceedsFromPaymentsForOtherFinancingA...
# 30  us-gaap_NetCashProvidedByUsedInFinancingActivi...
# 31  us-gaap_CashCashEquivalentsRestrictedCashAndRe...
# 32  us-gaap_CashCashEquivalentsRestrictedCashAndRe...
# 33    us-gaap_SupplementalCashFlowInformationAbstract
# 34                         us-gaap_IncomeTaxesPaidNet
#
#                                                 label  2024-09-28  2023-09-30  \
# 0   Cash, cash equivalents, and restricted cash an...
# 1                               Operating activities:
# 2                                          Net Income     $93,736     $96,995
# 3   Adjustments to reconcile net income to cash ge...
# 4                       Depreciation and amortization     $11,445     $11,519
# 5                    Share-based compensation expense     $11,688     $10,833
# 6                                               Other    $(2,266)    $(2,227)
# 7        Changes in operating assets and liabilities:
# 8                            Accounts receivable, net    $(3,788)    $(1,688)
# 9                        Vendor non-trade receivables    $(1,356)      $1,271
# 10                                        Inventories    $(1,046)    $(1,618)
# 11               Other current and non-current assets   $(11,731)    $(5,684)
# 12                                   Accounts Payable      $6,020    $(1,889)
# 13          Other current and non-current liabilities     $15,552      $3,031
# 14                 Net Cash from Operating Activities    $118,254    $110,543
# 15                              Investing activities:
# 16                 Purchases of marketable securities   $(48,656)   $(29,513)
# 17  Proceeds from Maturities, Prepayments and Call...     $51,211     $39,686
# 18            Proceeds from Sale of Debt Securities,      $11,135      $5,828
# 19         Payments for Property, Plant and Equipment    $(9,447)   $(10,959)
# 20                                              Other    $(1,308)    $(1,337)
# 21                 Net Cash from Investing Activities      $2,935      $3,705
# 22                              Financing activities:
# 23       Tax Withholding for Share-Based Compensation    $(5,441)    $(5,431)
# 24                              Payments of Dividends   $(15,234)   $(15,025)
# 25                        Repurchases of common stock   $(94,949)   $(77,550)
# 26           Proceeds from Issuance of Long-Term Debt                 $5,228
# 27                            Repayments of term debt    $(9,958)   $(11,151)
# 28     Proceeds from (Repayments of) Commercial Paper      $3,960    $(3,978)
# 29                                              Other      $(361)      $(581)
# 30                 Net Cash from Financing Activities  $(121,983)  $(108,488)
# 31                                 Net Change in Cash      $(794)      $5,760
# 32  Cash, cash equivalents, and restricted cash an...
# 33                 Supplemental cash flow disclosure:
# 34                                 Income Tax Expense     $26,102     $18,679
#
#     2022-09-24  level  abstract  dimension
# 0                   1     False      False
# 1                   1     False      False
# 2      $99,803      2     False      False
# 3                   2     False      False
# 4      $11,104      3     False      False
# 5       $9,038      3     False      False
# 6       $1,006      3     False      False
# 7                   3     False      False
# 8     $(1,823)      4     False      False
# 9     $(7,520)      4     False      False
# 10      $1,484      4     False      False
# 11    $(6,499)      4     False      False
# 12      $9,448      4     False      False
# 13      $6,110      4     False      False
# 14    $122,151      2     False      False
# 15                  1     False      False
# 16   $(76,923)      2     False      False
# 17     $29,917      2     False      False
# 18     $37,446      2     False      False
# 19   $(10,708)      2     False      False
# 20    $(2,086)      2     False      False
# 21   $(22,354)      2     False      False
# 22                  1     False      False
# 23    $(6,223)      2     False      False
# 24   $(14,841)      2     False      False
# 25   $(89,402)      2     False      False
# 26      $5,465      2     False      False
# 27    $(9,543)      2     False      False
# 28      $3,955      2     False      False
# 29      $(160)      2     False      False
# 30  $(110,749)      2     False      False
# 31   $(10,952)      1     False      False
# 32                  1     False      False
# 33                  1     False      False
# 34     $19,573      2     False      False
