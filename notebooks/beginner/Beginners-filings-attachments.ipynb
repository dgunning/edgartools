# %% [markdown]
# # Beginner's Guide: filings vs. filing and attachments of a filing
#
# This is a beginner's guide to clarify the concept of filings vs. filing and to introduce the use of attachments in edgartools

# %%
#!pip install -U edgartools   # Uncomment this to install the package in ter


from edgar import *
from edgar.xbrl import *

set_identity("John Doe john.doe@myEmail.com")   # Tell the SEC who you are

# %%
# Company("NVDA") with cik = 1045810

# Get a list of filings meeting the conditions on cik, form, and filing_date
filings = (Company(1045810).get_filings(form=["10-K", "10-Q"])   # get either 10-K or 10-Q
            .filter(filing_date="2023-01-01:2023-12-31")
          )
filings
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────── Filings for NVIDIA CORP [1045810] ─────────────────────────────────────╮
# │                                                                                                            │
# │   #   Form       Description                                          Filing Date   Accession Number       │
# │  ────────────────────────────────────────────────────────────────────────────────────────────────────────  │
# │   0   10-Q       Quarterly report for public companies                2023-11-21    0001045810-23-000227   │
# │   1   10-Q       Quarterly report for public companies                2023-08-28    0001045810-23-000175   │
# │   2   10-Q       Quarterly report for public companies                2023-05-26    0001045810-23-000093   │
# │   3   10-K       Annual report for public companies                   2023-02-24    0001045810-23-000017   │
# │                                                                                                            │
# ╰──────────────────────────── Company filings between 2023-02-24 and 2023-11-21 ─────────────────────────────╯

# %%
# Filtering for "10-K" alone returns an object of the EntityFilings class (note the plural in EntityFilings)
filings_still = filings.filter(form="10-K")

print(type(filings_still)) # show the type of the object
print(dir(filings_still))  # show the methods of the object
filings_still
# Out:
# <class 'edgar.entity.filings.EntityFilings'>
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__rich__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_get_by_accession_number', '_hash', '_head', '_original_state', '_page_index', '_sample', '_tail', 'cik', 'company_name', 'current', 'data', 'data_pager', 'date_range', 'docs', 'download', 'empty', 'end_date', 'filter', 'find', 'get', 'get_filing_at', 'head', 'latest', 'next', 'previous', 'sample', 'save', 'save_parquet', 'start_date', 'summarize', 'summary', 'tail', 'to_dict', 'to_pandas']
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────── Filings for NVIDIA CORP [1045810] ─────────────────────────────────────╮
# │                                                                                                            │
# │   #   Form       Description                                          Filing Date   Accession Number       │
# │  ────────────────────────────────────────────────────────────────────────────────────────────────────────  │
# │   0   10-K       Annual report for public companies                   2023-02-24    0001045810-23-000017   │
# │                                                                                                            │
# ╰──────────────────────────── Company filings between 2023-02-24 and 2023-02-24 ─────────────────────────────╯

# %%
# filings_still as an object of the EntityFilings class has no attachments method 

filings_still.attachments
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 # filings_still as an object of the EntityFilings class has no attachments method
# ----> 3 filings_still.attachments
#
# AttributeError: 'EntityFilings' object has no attribute 'attachments'

# %% [markdown]
# # filings_still[0] vs. filings_still: Note the different types and methods

# %%
# Choose the only filing in the list filings_still
filing = filings_still[0]  

# Note the different types and methods for filing = filings_still[0], as opposed to the list filings_still
print(type(filing))  # note EntityFiling, as opposed to EntityFilings
print(dir(filing))   # EntityFiling has the attachments method
# Out:
# <class 'edgar.entity.filings.EntityFiling'>
# ['_Filing__get_bm25_search_index', '_Filing__get_regex_search_index', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rich__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_download_filing_text', '_filing_homepage', '_local_path', '_sgml', 'acceptance_datetime', 'accession_no', 'accession_number', 'as_company_filing', 'attachments', 'base_dir', 'cik', 'company', 'data_object', 'docs', 'document', 'exhibits', 'file_number', 'filing_date', 'filing_directory', 'filing_url', 'form', 'from_dict', 'from_json', 'from_sgml', 'full_text_submission', 'get_entity', 'header', 'home', 'homepage', 'homepage_url', 'html', 'index_header_url', 'index_headers', 'is_inline_xbrl', 'is_xbrl', 'items', 'load', 'markdown', 'obj', 'open', 'open_homepage', 'period_of_report', 'primary_doc_description', 'primary_document', 'primary_documents', 'related_filings', 'report_date', 'reports', 'save', 'search', 'sections', 'serve', 'sgml', 'size', 'statements', 'summary', 'text', 'text_url', 'to_dict', 'url', 'view', 'xbrl', 'xml']

# %%
# open the filing and its home page in a browser
filing.open()  
filing.open_homepage()

# %%
# Show the list of attachments in a table

filing.attachments
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                        Attachments
# ╭─────┬────────────────────────────────┬──────────────────────────────────────────────────────────────┬────────────
# │ Seq │ Document                       │ Description                                                  │ Type
# ├─────┼────────────────────────────────┼──────────────────────────────────────────────────────────────┼────────────
# │ 1   │ nvda-20230129.htm              │ 10-K                                                         │ 📜  10-K
# │ 2   │ nvidia-202310xkdescription.htm │ EX-4.6                                                       │ 📋  EX-4.6
# │ 3   │ nvidia-eipardecember12022.htm  │ EX-10.2                                                      │ 📋  EX-10.2
# │ 4   │ a2007planglobalrsuagreemen.htm │ EX-10.14                                                     │ 📋  EX-10.1
# │ 5   │ listofregistrantssubsidiar.htm │ LIST OF REGISTRANTS SUBSIDIARIES                             │ 📋  EX-21.1
# │ 6   │ consentofindependentregist.htm │ CONSENT OF INDEPENDENT REGISTERED PUBLIC ACCOUNTING FIRM     │ 📋  EX-23.1
# │ 7   │ nvda-2023xex311.htm            │ 302 CERTIFICATION OF CEO                                     │ 📋  EX-31.1
# │ 8   │ nvda-2023xex312.htm            │ 302 CERTIFICATION OF CFO                                     │ 📋  EX-31.2
# │ 9   │ nvda-2023xex321.htm            │ 906 CERTIFICATION OF CEO                                     │ 📋  EX-32.1
# │ 10  │ nvda-2023xex322.htm            │ 906 CERTIFICATION OF CFO                                     │ 📋  EX-32.2
# │ 11  │ nvda-20230129.xsd              │ XBRL TAXONOMY EXTENSION SCHEMA DOCUMENT                      │ 🔰  EX-101.
# │ 12  │ nvda-20230129_cal.xml          │ XBRL TAXONOMY EXTENSION CALCULATION LINKBASE DOCUMENT        │ 📊  EX-101.
# │ 13  │ nvda-20230129_def.xml          │ XBRL TAXONOMY EXTENSION DEFINITION LINKBASE DOCUMENT         │ 📚  EX-101.
# │ 99  │ R82.htm                        │ Shareholders' Equity (Details)                               │ 🌍  HTML
# │ 100 │ R83.htm                        │ Employee Retirement Plans (Details)                          │ 🌍  HTML
# │ 101 │ R84.htm                        │ Segment Information - Narrative (Details)                    │ 🌍  HTML
# │ 102 │ R85.htm                        │ Segment Information - Reportable Segments (Details)          │ 🌍  HTML
# │ 103 │ R86.htm                        │ Segment Information - Reconciling Items (Details)            │ 🌍  HTML
# │ 104 │ R87.htm                        │ Segment Information - Revenue and Long-lived Assets by       │ 🌍  HTML
# │     │                                │ Region (Details)                                             │
# │ 105 │ R88.htm                        │ Segment Information - Schedule of Revenue by Market          │ 🌍  HTML
# │     │                                │ (Details)                                                    │
# │ 106 │ R89.htm                        │ Schedule II - Valuation and Qualifying Accounts (Details)    │ 🌍  HTML
# │ 107 │ nvda-20230129_htm.xml          │ IDEA: XBRL DOCUMENT                                          │ 🔷  XML
# │ 108 │ Financial_Report.xlsx          │ IDEA: XBRL DOCUMENT                                          │ 📊  EXCEL
# │ 109 │ Show.js                        │ IDEA: XBRL DOCUMENT                                          │ 📄  JS
# │ 110 │ report.css                     │ IDEA: XBRL DOCUMENT                                          │ 📃  CSS
# │ 111 │ FilingSummary.xml              │ IDEA: XBRL DOCUMENT                                          │ 🔷  XML
# │ 114 │ MetaLinks.json                 │ IDEA: XBRL DOCUMENT                                          │ 📝  JSON
# │ 115 │ 0001045810-23-000017-xbrl.zip  │ IDEA: XBRL DOCUMENT                                          │ 📦  ZIP
# ╰─────┴────────────────────────────────┴──────────────────────────────────────────────────────────────┴────────────

# %%
# View attachments[19]

# 19  │ R2.htm                         │ Audit Information                                            │ 🌍  HTML  
filing.attachments[19].view()
# Out:
#
#   Audit Information
#   Jan. 29, 2023                            12 Months Ended
#  ──────────────────────────────────────────────────────────
#   Audit Information [Abstract]
#   Auditor Firm ID                                      238
#   Auditor Name                  PricewaterhouseCoopers LLP
#   Auditor Location                    San Jose, California

# %%
# Show the methods of the attachments object
# Note: Scroll to the right to see all the methods

print(dir(filing.attachments))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__module__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__rich__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_attachments', '_download_all_attachments', 'data_files', 'documents', 'download', 'exhibits', 'get_by_index', 'get_by_sequence', 'get_report', 'graphics', 'load', 'n', 'primary_documents', 'primary_html_document', 'primary_xml_document', 'query', 'serve', 'sgml', 'text_document']

# %%
# More details on using the query method of attachments 

help(filing.attachments.query)
# Out:
# Help on method query in module edgar.attachments:
#
# query(query_str: str, include_data_files: bool = True) method of edgar.attachments.Attachments instance
#     Query attachments based on a simple query string.
#     Supports conditions on 'document', 'description', and 'document_type'.
#     Example query: "document.endswith('.htm') and 'RELEASE' in description and document_type in ['EX-99.1', 'EX-99', 'EX-99.01']"

# %%
# Select attachments[19] by querying on document 
# (i.e., the Document column in the previously displayed attachments table)

# 19  │ R2.htm                         │ Audit Information                                            │ 🌍  HTML  
print(filing.attachments.query("document == 'R2.htm'"))

#View the selected attachment
filing.attachments.query("document == 'R2.htm'").data_files[0].view()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                             Attachments
# ╭─────┬──────────┬──────────────────────────────────────────────────────────────┬──────────────────╮
# │ Seq │ Document │ Description                                                  │ Type             │
# ├─────┼──────────┼──────────────────────────────────────────────────────────────┼──────────────────┤
# │ 19  │ R2.htm   │ Audit Information                                            │ 🌍  HTML         │
# ╰─────┴──────────┴──────────────────────────────────────────────────────────────┴──────────────────╯
#
#   Audit Information
#   Jan. 29, 2023                            12 Months Ended
#  ──────────────────────────────────────────────────────────
#   Audit Information [Abstract]
#   Auditor Firm ID                                      238
#   Auditor Name                  PricewaterhouseCoopers LLP
#   Auditor Location                    San Jose, California

# %%
print(type(filing.attachments.query("document == 'R2.htm'").data_files[0]))
print(dir(filing.attachments.query("document == 'R2.htm'").data_files[0]))
# Out:
# <class 'edgar.attachments.Attachment'>
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rich__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'content', 'description', 'display_extension', 'document', 'document_type', 'download', 'empty', 'extension', 'is_binary', 'is_html', 'is_report', 'is_text', 'is_xml', 'ixbrl', 'path', 'purpose', 'sequence_number', 'sgml', 'sgml_document', 'size', 'text', 'url', 'validate_sequence_number', 'view']

# %%
print(filing.attachments.query("document == 'R2.htm'").data_files[0].document)
print(filing.attachments.query("document == 'R2.htm'").data_files[0].document_type)

# Error: Show the wrong description of the selected attachment
# Note: Should be "Audit Information" instead of "IDEA: XBRL DOCUMENT"
print(filing.attachments.query("document == 'R2.htm'").data_files[0].description)
# Out:
# R2.htm
# HTML
# IDEA: XBRL DOCUMENT

# %%
filing.attachments.query("document == 'R2.htm'").data_files[0].purpose
# Out:
# 'Audit Information'

# %%
filing.attachments.query("description.startswith('C')")

# Error: Only show this attachment
#│ 6   │ consentofindependentregist.htm │ CONSENT OF INDEPENDENT REGISTERED PUBLIC ACCOUNTING FIRM     │ 📋  EX-23.1

# Note: Fail to capture the following attachments
#│ 18  │ R1.htm                         │ Cover Page                                                   │ 🌍  HTML   
#│ 20  │ R3.htm                         │ CONSOLIDATED STATEMENTS OF INCOME                            │ 🌍  HTML   
#│ 21  │ R4.htm                         │ CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME              │ 🌍  HTML
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                                        Attachments
# ╭─────┬────────────────────────────────┬──────────────────────────────────────────────────────────────┬────────────
# │ Seq │ Document                       │ Description                                                  │ Type
# ├─────┼────────────────────────────────┼──────────────────────────────────────────────────────────────┼────────────
# │ 6   │ consentofindependentregist.htm │ CONSENT OF INDEPENDENT REGISTERED PUBLIC ACCOUNTING FIRM     │ 📋  EX-23.1
# ╰─────┴────────────────────────────────┴──────────────────────────────────────────────────────────────┴────────────

# %%
# Display some other attributes of the selected attachment

print(filing.attachments.query("document == 'R2.htm'").data_files[0].url)
print(filing.attachments.query("document == 'R2.htm'").data_files[0].is_html())
filing.attachments.query("document == 'R2.htm'").data_files[0].content
# Out:
# https://www.sec.gov/Archives/edgar/data/1045810/000104581023000017/R2.htm
# True
# '<html>\n<head>\n<title></title>\n<link rel="stylesheet" type="text/css" href="include/report.css">\n<script type="text/javascript" src="Show.js">/* Do Not Remove This Comment */</script><script type="text/javascript">\n\t\t\t\t\t\t\tfunction toggleNextSibling (e) {\n\t\t\t\t\t\t\tif (e.nextSibling.style.display==\'none\') {\n\t\t\t\t\t\t\te.nextSibling.style.display=\'block\';\n\t\t\t\t\t\t\t} else { e.nextSibling.style.display=\'none\'; }\n\t\t\t\t\t\t\t}</script>\n</head>\n<body>\n<span style="display: none;">v3.22.4</span><table class="report" border="0" cellspacing="2" id="idm139926120565472">\n<tr>\n<th class="tl" colspan="1" rowspan="2"><div style="width: 200px;"><strong>Audit Information<br></strong></div></th>\n<th class="th" colspan="1">12 Months Ended</th>\n</tr>\n<tr><th class="th"><div>Jan. 29, 2023</div></th></tr>\n<tr class="re">\n<td class="pl" style="border-bottom: 0px;" valign="top"><a class="a" href="javascript:void(0);" onclick="Show.showAR( this, \'defref_nvda_AuditInformationAbstract\', window );"><strong>Audit Information [Abstract]</strong></a></td>\n<td class="text">&#160;<span></span>\n</td>\n</tr>\n<tr class="ro">\n<td class="pl" style="border-bottom: 0px;" valign="top"><a class="a" href="javascript:void(0);" onclick="Show.showAR( this, \'defref_dei_AuditorFirmId\', window );">Auditor Firm ID</a></td>\n<td class="text">238<span></span>\n</td>\n</tr>\n<tr class="re">\n<td class="pl" style="border-bottom: 0px;" valign="top"><a class="a" href="javascript:void(0);" onclick="Show.showAR( this, \'defref_dei_AuditorName\', window );">Auditor Name</a></td>\n<td class="text">PricewaterhouseCoopers LLP<span></span>\n</td>\n</tr>\n<tr class="ro">\n<td class="pl" style="border-bottom: 0px;" valign="top"><a class="a" href="javascript:void(0);" onclick="Show.showAR( this, \'defref_dei_AuditorLocation\', window );">Auditor Location</a></td>\n<td class="text">San Jose, California<span></span>\n</td>\n</tr>\n</table>\n<div style="display: none;">\n<table border="0" cellpadding="0" cellspacing="0" class="authRefData" style="display: none;" id="defref_dei_AuditorFirmId">\n<tr><td class="hide"><a style="color: white;" href="javascript:void(0);" onclick="Show.hideAR();">X</a></td></tr>\n<tr><td><div class="body" style="padding: 2px;">\n<a href="javascript:void(0);" onclick="Show.toggleNext( this );">- Definition</a><div><p>PCAOB issued Audit Firm Identifier</p></div>\n<a href="javascript:void(0);" onclick="Show.toggleNext( this );">+ References</a><div style="display: none;"><p>Reference 1: http://www.xbrl.org/2003/role/presentationRef<br> -Publisher SEC<br> -Name Form 10-K<br> -Number 249<br> -Section 310<br><br>Reference 2: http://www.xbrl.org/2003/role/presentationRef<br> -Publisher SEC<br> -Name Form 20-F<br> -Number 249<br> -Section 220<br> -Subsection f<br><br>Reference 3: http://www.xbrl.org/2003/role/presentationRef<br> -Publisher SEC<br> -Name Form 40-F<br> -Number 249<br> -Section 240<br> -Subsection f<br></p></div>\n<a href="javascript:void(0);" onclick="Show.toggleNext( this );">+ Details</a><div style="display: none;"><table border="0" cellpadding="0" cellspacing="0">\n<tr>\n<td><strong> Name:</strong></td>\n<td style="white-space:nowrap;">dei_AuditorFirmId</td>\n</tr>\n<tr>\n<td style="padding-right: 4px;white-space:nowrap;"><strong> Namespace Prefix:</strong></td>\n<td>dei_</td>\n</tr>\n<tr>\n<td><strong> Data Type:</strong></td>\n<td>dei:nonemptySequenceNumberItemType</td>\n</tr>\n<tr>\n<td><strong> Balance Type:</strong></td>\n<td>na</td>\n</tr>\n<tr>\n<td><strong> Period Type:</strong></td>\n<td>duration</td>\n</tr>\n</table></div>\n</div></td></tr>\n</table>\n<table border="0" cellpadding="0" cellspacing="0" class="authRefData" style="display: none;" id="defref_dei_AuditorLocation">\n<tr><td class="hide"><a style="color: white;" href="javascript:void(0);" onclick="Show.hideAR();">X</a></td></tr>\n<tr><td><div class="body" style="padding: 2px;">\n<a href="javascript:void(0);" onclick="Show.toggleNext( t ...

# %%
# View the attachment with Segment Information 
# │ 43  │ R26.htm                        │ Segment Information                                          │ 🌍  HTML   

filing.attachments[43].view()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#
#   Segment Information
#   Jan. 29, 2023                 12 Months Ended
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   Segment Reporting [Abstract]
#                                 Compute & Networking
#                                   Year Ended January 29, 2023:              (In millions)       Graphics
#                                 All Other       Consolidated
#                                  ───────────────────────────────────────────────────────────────────────────────…
#                                   Revenue                         $                15,068    $    11,906    $
#                                 —    $        26,974
#                                   Operating income (loss)         $                 5,083    $     4,552    $
#                                 -5,411    $         4,224
#   Segment Information             Year Ended January 30, 2022:
#                                   Revenue                         $                11,046    $    15,868    $
#                                 —    $        26,914
#                                   Operating income (loss)         $                 4,598    $     8,492    $
#                                 -3,049    $        10,041
#                                   Year Ended January 31, 2021:
#                                   Revenue                         $                 6,841    $     9,834    $
#                                 —    $        16,675
#                                   Operating income (loss)         $                 2,548    $     4,612    $
#                                 -2,628    $         4,532

# %%
# View the attachment with Segment Information (Tables)
# │ 58  │ R41.htm                        │ Segment Information (Tables)                                 │ 🌍  HTML   

filing.attachments[58].view()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#
#   Segment Information (Tables)
#   Jan. 29, 2023                       12 Months Ended
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   Segment Reporting [Abstract]
#                                       Compute & Networking
#                                         Year Ended January 29, 2023:              (In millions)       Graphics
#                                       All Other       Consolidated
#                                        ─────────────────────────────────────────────────────────────────────────…
#                                         Revenue                         $                15,068    $    11,906
#                                       $          —    $        26,974
#                                         Operating income (loss)         $                 5,083    $     4,552
#                                       $     -5,411    $         4,224
#   Schedule of Reportable Segments       Year Ended January 30, 2022:
#                                         Revenue                         $                11,046    $    15,868
#                                       $          —    $        26,914
#                                         Operating income (loss)         $                 4,598    $     8,492
#                                       $     -3,049    $        10,041
#                                         Year Ended January 31, 2021:
#                                         Revenue                         $                 6,841    $     9,834
#                                       $          —    $        16,675
#                                         Operating income (loss)         $                 2,548    $     4,612
#                                       $     -2,628    $         4,532
#                                       Year Ended
#                                                                            January 29,       January 30,
#                                       January 31,
#                                                                                   2023              2022
#                                       2021
#                                        ─────────────────────────────────────────────────────────────────────────…
#                                         Revenue:                          -In millions
#   Schedule of Revenue by Geographic     United States                  $         8,292    $        4,349    $
#   Regions                             3,214
#                                         Taiwan                                   6,986             8,544
#                                       4,531
#                                         China (including Hong Kong)              5,785             7,111
#                                       3,886
#                                         Other countries                          5,911             6,910
#                                       5,044
#                                         Total revenue                  $        26,974    $       26,914    $
#                                       16,675
#                                       Year Ended
#                                                                           January 29,       January 30,
#                                       January 31,
#                                                                                  2023              2022
#                                       2021
#                                        ─────────────────────────────────────────────────────────────────────────…
#                                         Revenue:                         -In millions
#                                         Data Center                   $        15,005    $       10,613    $
#   Schedule of Revenue by Specialized  6,696
#   Markets                               Gaming                                  9,067            12,462
#                                       7,759
#                                         Professional Visualization              1,544             2,111
#                                       1,053
#                                         Automotive                                903               566
#                                       536
#                                         OEM & Other                               455             1,162
#                                       631
#                                         Total revenue                 $        26,974    $       26,914    $
#                                       16,675
#                                       January 29,       January 30,
#                                                                               2023              2022
#                                        ──────────────────────────────────────────────────────────────
#   Schedule of Long-Lived Assets by      Long-lived assets:            -In millions
#   Geographic Region                     United States              $         2,587    $        2,023
#                                         Taiwan                                 702               379
#                                         Israel                                 283               185
#                                         Other countries                        235               191
#                                         Total long-lived assets    $         3,807    $        2,778

# %%
# Attachment or its content has no to_dataframe method

print(type(filing.attachments[58]))
print(dir(filing.attachments[58]))
print(type(filing.attachments[58].content))
print(dir(filing.attachments[58].content))
# Out:
# <class 'edgar.attachments.Attachment'>
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rich__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'content', 'description', 'display_extension', 'document', 'document_type', 'download', 'empty', 'extension', 'is_binary', 'is_html', 'is_report', 'is_text', 'is_xml', 'ixbrl', 'path', 'purpose', 'sequence_number', 'sgml', 'sgml_document', 'size', 'text', 'url', 'validate_sequence_number', 'view']
# <class 'str'>
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'removeprefix', 'removesuffix', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']
