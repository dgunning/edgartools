# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/dgunning/edgartools/blob/main/notebooks/XBRL2-NonFinancialStatements.ipynb)
#
# # Access Non-Financial Statements and Disclosures from SEC XBRL with Python -- Free, No API Key
#
# Use **edgartools** to access non-financial disclosures (segment data, equity details, share-based compensation, commitments) from SEC XBRL filings -- completely free, no API key required.

# %% [markdown]
# # Non-Financial Statements

# %%
#!pip install edgartools

# %%
from edgar import *
from edgar.xbrl import *

# %%
c = Company("AAPL")
filings = c.latest("10-K", 2)
xbrl = XBRL.from_filing(filings[1])
filing = filings[1]

# %%
filing.reports
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────── Reports ────────────────────────────────────────────╮
# │                                                                                                │
# │   #    Report                                                         Category       File      │
# │  ────────────────────────────────────────────────────────────────────────────────────────────  │
# │   1    Cover Page                                                     Cover          R1.htm    │
# │                                                                                                │
# │   2    Auditor Information                                            Cover          R2.htm    │
# │                                                                                                │
# │   3    CONSOLIDATED STATEMENTS OF OPERATIONS                          Statements     R3.htm    │
# │                                                                                                │
# │   4    CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME                Statements     R4.htm    │
# │                                                                                                │
# │   5    CONSOLIDATED BALANCE SHEETS                                    Statements     R5.htm    │
# │                                                                                                │
# │   6    CONSOLIDATED BALANCE SHEETS (Parenthetical)                    Statements     R6.htm    │
# │                                                                                                │
# │   7    CONSOLIDATED STATEMENTS OF SHAREHOLDERS' EQUITY                Statements     R7.htm    │
# │                                                                                                │
# │   8    CONSOLIDATED STATEMENTS OF CASH FLOWS                          Statements     R8.htm    │
# │                                                                                                │
# │   9    Summary of Significant Accounting Policies                     Notes          R9.htm    │
# │                                                                                                │
# │   10   Revenue                                                        Notes          R10.htm   │
# │                                                                                                │
# │   11   Earnings Per Share                                             Notes          R11.htm   │
# │                                                                                                │
# │   12   Financial Instruments                                          Notes          R12.htm   │
# │                                                                                                │
# │   13   Property, Plant and Equipment                                  Notes          R13.htm   │
# │                                                                                                │
# │   14   Consolidated Financial Statement Details                       Notes          R14.htm   │
# │                                                                                                │
# │   15   Income Taxes                                                   Notes          R15.htm   │
# │                                                                                                │
# │   16   Leases                                                         Notes          R16.htm   │
# │                                                                                                │
# │   17   Debt                                                           Notes          R17.htm   │
# │                                                                                                │
# │   18   Shareholders' Equity                                           Notes          R18.htm   │
# │                                                                                                │
# │   19   Share-Based Compensation                                       Notes          R19.htm   │
# │                                                                                                │
# │   20   Commitments, Contingencies and Supply Concentrations           Notes          R20.htm   │
# │                                                                                                │
# │   21   Segment Information and Geographic Data                        Notes          R21.htm   │
# │                                                                                                │
# │   22   Pay vs Performance Disclosure                                  Notes          R22.htm   │
# │                                                                                                │
# │   23   Insider Trading Arrangements                                   Notes          R23.htm   │
# │                                                                                                │
# │   24   Summary of Significant Accounting Policies (Policies)          Policies       R24.htm   │
# │                                                                                                │
# │   25   Revenue (Tables)                                               Tables         R25.htm   │
# │                                                                                                │
# │   26   Earnings Per Share (Tables)                                    Tables         R26.htm   │
# │                                                                                                │
# │   27   Financial Instruments (Tables)                                 Tables         R27.htm   │
# │                                                                                                │
# │   28   Property, Plant and Equipment (Tables)                         Tables         R28.htm   │
# │                                                                                                │
# │   29   Consolidated Financial Statement Details (Tables)              Tables         R29.htm   │
# │                                                                                                │
# │   30   Income Taxes (Tables)                                          Tables         R30.htm   │
# │                                                                                                │
# │   31   Leases (Tables)                                                Tables         R31.htm   │
# │                                                                                                │
# │   32   Debt (Tables)                                                  Tables         R32.htm   │
# │                                                                                                │
# │   33   Shareholders' Equity (Tables)                                  Tables         R33.htm   │
# │                                                                                                │
# │   34   Share-Based Compensation (Tables)                              Tables         R34.htm   │
# │                                                                                                │
# │   35   Commitments, Contingencies and Supply Concentrations           Tables         R35.htm   │
# │        (Tables)                                                                                │
# │                                                                                                │
# │   36   Segment Information and Geographic Data (Tables)               Tables         R36.htm   │
# │                                                                                                │
# │   37   Revenue - Additional Information (Details)                     Details        R37.htm   │
# │                                                                                                │
# │   38   Revenue - Net Sales Disaggregated by Significant Products      Details        R38.htm   │
# │        and Services (Details)                                                                  │
# │                                                                                                │
# │   39   Revenue - Deferred Revenue, Expected Timing of Realization     Details        R39.htm   │
# │        (Details)                                                                               │
# │                                                                                                │
# │   40   Earnings Per Share - Computation of Basic and Diluted          Details        R40.htm   │
# │        Earnings Per Share (Details)                                                            │
# │                                                                                                │
# │   41   Earnings Per Share - Additional Information (Details)          Details        R41.htm   │
# │                                                                                                │
# │   42   Financial Instruments - Cash, Cash Equivalents and             Details        R42.htm   │
# │        Marketable Securities (Details)                                                         │
# │                                                                                                │
# │   43   Financial Instruments - Non-Current Marketable Debt            Details        R43.htm   │
# │        Securities by Contractual Maturity (Details)                                            │
# │                                                                                                │
# │   44   Financial Instruments - Additional Information (Details)       Details        R44.htm   │
# │                                                                                                │
# │   45   Financial Instruments - Notional Amounts Associated with       Details        R45.htm   │
# │        Derivative Instruments (Details)                                                        │
# │                                                                                                │
# │   46   Financial Instruments - Gross Fair Values of Derivative        Details        R46.htm   │
# │        Assets and Liabilities (Details)                                                        │
# │                                                                                                │
# │   47   Financial Instruments - Derivative Instruments Designated as   Details        R47.htm   │
# │        Fair Value Hedges and Related Hedged Items (Details)                                    │
# │                                                                                                │
# │   48   Property, Plant and Equipment - Gross Property, Plant and      Details        R48.htm   │
# │        Equipment by Major Asset Class and Accumulated Depreciation                             │
# │        (Details)                                                                               │
# │                                                                                                │
# │   49   Property, Plant, and Equipment - Additional Information        Details        R49.htm   │
# │        (Details)                                                                               │
# │                                                                                                │
# │   50   Consolidated Financial Statement Details ??? Other             Details        R50.htm   │
# │        Non-Current Assets (Details)                                                            │
# │                                                                                                │
# │   51   Consolidated Financial Statement Details ??? Other Current     Details        R51.htm   │
# │        Liabilities (Details)                                                                   │
# │                                                                                                │
# │   52   Consolidated Financial Statement Details - Other Non-Current   Details        R52.htm   │
# │        Liabilities (Details)                                                                   │
# │                                                                                                │
# │   53   Consolidated Financial Statement Details - Other               Details        R53.htm   │
# │        Income/(Expense), Net (Details)                                                         │
# │                                                                                                │
# │   54   Income Taxes - Provision for Income Taxes (Details)            Details        R54.htm   │
# │                                                                                                │
# │   55   Income Taxes - Additional Information (Details)                Details        R55.htm   │
# │                                                                                                │
# │   56   Income Taxes - Reconciliation of Provision for Income Taxes    Details        R56.htm   │
# │        to Amount Computed by Applying the Statutory Federal Income                             │
# │        Tax Rate to Income Before Provision for Income Taxes                                    │
# │        (Details)                                                                               │
# │                                                                                                │
# │   57   Income Taxes - Significant Components of Deferred Tax Assets   Details        R57.htm   │
# │        and Liabilities (Details)                                                               │
# │                                                                                                │
# │   58   Income Taxes - Aggregate Changes in Gross Unrecognized Tax     Details        R58.htm   │
# │        Benefits (Details)                                                                      │
# │                                                                                                │
# │   59   Leases - Additional Information (Details)                      Details        R59.htm   │
# │                                                                                                │
# │   60   Leases - ROU Assets and Lease Liabilities (Details)            Details        R60.htm   │
# │                                                                                                │
# │   61   Leases - Lease Liability Maturities (Details)                  Details        R61.htm   │
# │                                                                                                │
# │   62   Debt - Additional Information (Details)                        Details        R62.htm   │
# │                                                                                                │
# │   63   Debt - Summary of Cash Flows Associated with Commercial        Details        R63.htm   │
# │        Paper (Details)                                                                         │
# │                                                                                                │
# │   64   Debt - Summary of Term Debt (Details)                          Details        R64.htm   │
# │                                                                                                │
# │   65   Debt - Future Principal Payments for Term Debt (Details)       Details        R65.htm   │
# │                                                                                                │
# │   66   Shareholders' Equity - Additional Information (Details)        Details        R66.htm   │
# │                                                                                                │
# │   67   Shareholders' Equity - Shares of Common Stock (Details)        Details        R67.htm   │
# │                                                                                                │
# │   68   Share-Based Compensation - Additional Information (Details)    Details        R68.htm   │
# │                                                                                                │
# │   69   Share-Based Compensation - Restricted Stock Unit Activity      Details        R69.htm   │
# │        and Related Information (Details)                                                       │
# │                                                                                                │
# │   70   Share-Based Compensation - Summary of Share-Based              Details        R70.htm   │
# │        Compensation Expense and the Related Income Tax Benefit                                 │
# │        (Details)                                                                               │
# │                                                                                                │
# │   71   Commitments, Contingencies and Supply Concentrations -         Details        R71.htm   │
# │        Future Payments Under Unconditional Purchase Obligations                                │
# │        (Details)                                                                               │
# │                                                                                                │
# │   72   Segment Information and Geographic Data - Information by       Details        R72.htm   │
# │        Reportable Segment (Details)                                                            │
# │                                                                                                │
# │   73   Segment Information and Geographic Data - Reconciliation of    Details        R73.htm   │
# │        Segment Operating Income to the Consolidated Statements of                              │
# │        Operations (Details)                                                                    │
# │                                                                                                │
# │   74   Segment Information and Geographic Data - Net Sales            Details        R74.htm   │
# │        (Details)                                                                               │
# │                                                                                                │
# │   75   Segment Information and Geographic Data - Long-Lived Assets    Details        R75.htm   │
# │        (Details)                                                                               │
# │                                                                                                │
# │   -    All Reports                                                                             │
# │                                                                                                │
# ╰────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
filing.reports[72].view()
# Out:
#
#   Segment Information and Geographic Data -
#   Information by Reportable Segment (Details) - USD                 12 Months Ended
#   ($)$ in Millions                                   Sep. 30, 2023    Sep. 24, 2022  Sep. 25, 2021
#  ──────────────────────────────────────────────────────────────────────────────────────────────────
#   Segment Reporting Information [Line Items]
#   Net sales                                              $ 383,285        $ 394,328      $ 365,817
#   Operating income                                         114,301          119,437        108,949
#   Americas
#   Segment Reporting Information [Line Items]
#   Net sales                                                162,560          169,658        153,306
#   Operating income                                          60,508           62,683         53,382
#   Europe
#   Segment Reporting Information [Line Items]
#   Net sales                                                 94,294           95,118         89,307
#   Operating income                                          36,098           35,233         32,505
#   Greater China
#   Segment Reporting Information [Line Items]
#   Net sales                                                 72,559           74,200         68,366
#   Operating income                                          30,328           31,153         28,504
#   Japan
#   Segment Reporting Information [Line Items]
#   Net sales                                                 24,257           25,977         28,482
#   Operating income                                          11,888           12,257         12,798
#   Rest of Asia Pacific
#   Segment Reporting Information [Line Items]
#   Net sales                                                 29,615           29,375         26,356
#   Operating income                                        $ 12,066         $ 11,569        $ 9,817

# %% [markdown]
# ## All Statements

# %%
statements = xbrl.statements
statements
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Financial Statements
#
#   #     Name                                           Type                  Parenthetical
#  ───────────────────────────────────────────────────────────────────────────────────────────
#   4     CONSOLIDATEDBALANCESHEETS                      BalanceSheet
#   7     CONSOLIDATEDSTATEMENTSOFCASHFLOWS              CashFlowStatement
#   3     CONSOLIDATEDSTATEMENTSOFCOMPREHENSIVEINCOME    ComprehensiveIncome
#   2     CONSOLIDATEDSTATEMENTSOFOPERATIONS             IncomeStatement
#   6     CONSOLIDATEDSTATEMENTSOFSHAREHOLDERSEQUITY     StatementOfEquity
#   64    ShareholdersEquitySharesofCommonStockDetails   StatementOfEquity
#
# Notes to Financial Statements
#
#   #     Name                                             Type                 Parenthetical
#  ────────────────────────────────────────────────────────────────────────────────────────────
#   8     SummaryofSignificantAccountingPolicies           AccountingPolicies
#   21    SummaryofSignificantAccountingPoliciesPolicies   AccountingPolicies
#
# Disclosures
#
#   #     Name                                                                   Type                Parenthetical
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   73    AwardTimingDisclosure                                                  Disclosures
#   75    ErrCompDisclosure                                                      Disclosures
#   76    PvpDisclosure                                                          Disclosures
#   20    SegmentInformationandGeographicData                                    SegmentDisclosure
#   69    SegmentInformationandGeographicDataInformationbyReportableSegmentDe…   SegmentDisclosure
#   72    SegmentInformationandGeographicDataLongLivedAssetsDetails              SegmentDisclosure
#   71    SegmentInformationandGeographicDataNetSalesDetails                     SegmentDisclosure
#   70    SegmentInformationandGeographicDataReconciliationofSegmentOperating…   SegmentDisclosure
#   33    SegmentInformationandGeographicDataTables                              SegmentDisclosure
#
# Document Sections
#
#   #     Name        Type        Parenthetical
#  ──────────────────────────────────────────────
#   0     CoverPage   CoverPage
#
# Other Sections
#
#   #     Name                                                           Type                        Parenthetical
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#   1     AuditorInformation
#   19    CommitmentsContingenciesandSupplyConcentrations
#   68    CommitmentsContingenciesandSupplyConcentrationsFuturePaymen…
#   32    CommitmentsContingenciesandSupplyConcentrationsTables
#   13    ConsolidatedFinancialStatementDetails
#   48    ConsolidatedFinancialStatementDetailsOtherCurrentLiabilitie…
#   50    ConsolidatedFinancialStatementDetailsOtherIncomeExpenseNetD…
#   47    ConsolidatedFinancialStatementDetailsOtherNonCurrentAssetsD…
#   49    ConsolidatedFinancialStatementDetailsOtherNonCurrentLiabili…
#   26    ConsolidatedFinancialStatementDetailsTables
#   16    Debt
#   59    DebtAdditionalInformationDetails
#   62    DebtFuturePrincipalPaymentsforTermDebtDetails
#   60    DebtSummaryofCashFlowsAssociatedwithCommercialPaperDetails
#   61    DebtSummaryofTermDebtDetails
#   29    DebtTables
#   10    EarningsPerShare
#   38    EarningsPerShareAdditionalInformationDetails
#   37    EarningsPerShareComputationofBasicandDilutedEarningsPerShar…
#   23    EarningsPerShareTables
#   11    FinancialInstruments
#   41    FinancialInstrumentsAdditionalInformationDetails
#   39    FinancialInstrumentsCashCashEquivalentsandMarketableSecurit…
#   44    FinancialInstrumentsDerivativeInstrumentsDesignatedasFairVa…
#   43    FinancialInstrumentsGrossFairValuesofDerivativeAssetsandLia…
#   40    FinancialInstrumentsNonCurrentMarketableDebtSecuritiesbyCon…
#   42    FinancialInstrumentsNotionalAmountsAssociatedwithDerivative…
#   24    FinancialInstrumentsTables
#   14    IncomeTaxes
#   52    IncomeTaxesAdditionalInformationDetails
#   55    IncomeTaxesAggregateChangesinGrossUnrecognizedTaxBenefitsDe…
#   51    IncomeTaxesProvisionforIncomeTaxesDetails
#   53    IncomeTaxesReconciliationofProvisionforIncomeTaxestoAmountC…
#   54    IncomeTaxesSignificantComponentsofDeferredTaxAssetsandLiabi…
#   27    IncomeTaxesTables
#   74    InsiderTradingArrangements
#   77    InsiderTradingPoliciesProc
#   15    Leases
#   56    LeasesAdditionalInformationDetails
#   58    LeasesLeaseLiabilityMaturitiesDetails
#   57    LeasesROUAssetsandLeaseLiabilitiesDetails
#   28    LeasesTables
#   12    PropertyPlantandEquipment
#   46    PropertyPlantandEquipmentAdditionalInformationDetails
#   45    PropertyPlantandEquipmentGrossPropertyPlantandEquipmentbyMa…
#   25    PropertyPlantandEquipmentTables
#   9     Revenue
#   34    RevenueAdditionalInformationDetails
#   36    RevenueDeferredRevenueExpectedTimingofRealizationDetails
#   35    RevenueNetSalesDisaggregatedbySignificantProductsandService…
#   22    RevenueTables
#   18    ShareBasedCompensation
#   65    ShareBasedCompensationAdditionalInformationDetails
#   66    ShareBasedCompensationRestrictedStockUnitActivityandRelated…
#   67    ShareBasedCompensationSummaryofShareBasedCompensationExpens…
#   31    ShareBasedCompensationTables
#   17    ShareholdersEquity
#   63    ShareholdersEquityAdditionalInformationDetails
#   30    ShareholdersEquityTables
#   5     CONSOLIDATEDBALANCESHEETSParenthetical                         BalanceSheetParenthetical   ✓

# %% [markdown]
# ## Disclosures

# %%
statements['SegmentInformationandGeographicDataInformationByReportableSegmentDetails']
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# SegmentInformationandGeographicDataInformationbyReportable
#               SegmentDetails (Standardized)
#                     Three Months Ended
#
#                                             Sep 30, 2023
#  ────────────────────────────────────────────────────────
#       Net sales:
#           Products                               298,085
#           Services                                85,200
#           iPhone                                 200,583
#           Mac                                     29,357
#           iPad                                    28,300
#           Wearables, Home and Accessories         39,845
#           Americas                               162,560
#           Europe                                  94,294
#           Greater China                           72,559
#           Japan                                   24,257
#           Rest of Asia Pacific                    29,615
#           U.S.                                   138,573
#           China                                   72,559
#           Other countries                        172,153
#       Operating income:
#           Americas                                60,508
#           Europe                                  36,098
#           Greater China                           30,328
#           Japan                                   11,888
#           Rest of Asia Pacific                    12,066
#           Operating segments                     150,888

# %%
statements[66]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ShareBasedCompensationRestrictedStockUnitActivityandRelatedInformationD
#                          etails (Standardized)
#                           Three Months Ended
#
#                                                          Sep 30, 2023
#  ─────────────────────────────────────────────────────────────────────
#         Number of Restricted Stock Units
#           Ending balance (in shares)
#           RSUs granted (in shares)                                 89
#           RSUs vested (in shares)                                 102
#           RSUs canceled (in shares)                                 8
#           Ending balance (in shares)
#         Weighted-Average Grant Date Fair Value Per RSU
#           Ending balance (in dollars per share)
#           RSUs granted (in dollars per share)                       0
#           RSUs vested (in dollars per share)                        0
#           RSUs canceled (in dollars per share)                      0
#           Ending balance (in dollars per share)
#         Aggregate Fair Value
#           Aggregate fair value of RSUs

# %% [markdown]
# ## Segmented Statements

# %%
statements[68]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# CommitmentsConting
# enciesandSupplyCon
# centrationsFutureP
# aymentsUnderUncond
# itionalPurchaseObl
#  igationsDetails
#   (Standardized)
#
#
#  ────────────────
#       2024
#       2025
#       2026
#       2027
#       2028
#       Thereafter
#       Total

# %%
statements[64]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                   Consolidated Statement of Equity (Standardized)
#                                                 Three Months Ended
#
#                                                                           September 30, 2023   September 24, 2022
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         Increase (Decrease) in Shares of Common Stock Outstanding [Roll
#   Forward]
#           Common Stock Shares Outstanding
#           Common stock repurchased (in shares)                                           471               568.59
#           Common stock issued, net of shares withheld for employee                     78.06                85.23
#   taxes (in shares)
#           Common Stock Shares Outstanding

# %%
statements[65]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                    DebtNarrativeDetails (Standardized)
#                             Fiscal Year Ended
#
#                                          Jan 26, 2025   January 26, 2025
#  ────────────────────────────────────────────────────────────────────────
#         Repayment of debt                                        (1,250)
#         Stated interest rate (percent)           0.00
#         Maximum borrowing capacity                575
#         Outstanding commercial paper

# %%
statements[67]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ShareBasedCompensationSummaryofShareBasedCompensationExpenseandtheRe
#             latedIncomeTaxBenefitDetails (Standardized)
#
#
#  ──────────────────────────────────────────────────────────────────
#     Share-based compensation expense
#     Income tax benefit related to share-based compensation expense

# %%
statements["SegmentInformationScheduleofRevenuebyMarketDetails"].role_or_type
# Out:
# 'SegmentInformationScheduleofRevenuebyMarketDetails'
