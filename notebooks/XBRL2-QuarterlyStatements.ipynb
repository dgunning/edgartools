# %% [markdown]
# # Quarterly Statements

# %%
#!pip install edgartools

# %%
from edgar import *
from rich import print
from edgar.xbrl2 import *
from edgar.reference.tickers import popular_us_stocks

# %%
# %load_ext rich
# Out:
# The rich extension is already loaded. To reload it, use:
#   %reload_ext rich

# %%
stocks = popular_us_stocks()
tickers =stocks.Ticker.to_list()
tickers[10]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 'V'

# %% [markdown]
# ## Quarterly Statements

# %%
def quarterly_statements(ticker):
    print(ticker)
    c = Company(ticker)
    filings = c.latest("10-Q", 20)
    xbrl0 = XBRL.from_filing(filings[0])
    balance_sheet = xbrl0.statements.balance_sheet()
    print(balance_sheet)

    income_statement = xbrl0.statements.income_statement()
    print(income_statement)

    #xbrl_last = XBRL.from_filing(filings[-1])
    #balance_sheet = xbrl_last.statements.balance_sheet()
    #print(balance_sheet)

quarterly_statements(tickers[1])
# Out:
# MSFT
#                     Consolidated Balance Sheets (Standardized)
#              Second Quarter Ended (In millions, except per share data)
#
#                                                       Dec 31, 2024   Sep 30, 2024
#  ─────────────────────────────────────────────────────────────────────────────────
#     Assets
#       Current assets:
#         Cash and Cash Equivalents                          $17,482
#         Short-term investments                             $54,073
#         Cash and Cash Equivalents                          $71,555
#         Accounts Receivable                                $48,188
#         Inventory                                             $909
#         Other Assets                                       $26,428
#         Total Current Assets                              $147,080
#       Property, Plant and Equipment                       $166,902
#       Operating lease right-of-use assets                  $22,816
#       Long-Term Investments                                $15,581
#       Goodwill                                            $119,191
#       Intangible Assets                                    $25,385
#       Other Assets                                         $36,943
#       Total Assets                                        $533,898
#     Liabilities and stockholders’ equity
#       Current liabilities:
#         Accounts Payable                                   $22,608
#         Short-Term Debt
#         Short-Term Debt                                     $5,248
#         Accrued Liabilities                                 $9,176
#         Short-term income taxes                             $6,056
#         Short-term unearned revenue                        $45,508
#         Other Liabilities                                  $20,286
#         Total Current Liabilities                         $108,882
#       Long-Term Debt                                       $39,722
#       Long-term income taxes                               $24,389
#       Long-term unearned revenue                            $2,537
#       Deferred income taxes                                 $2,513
#       Operating lease liabilities                          $17,254
#       Other Liabilities                                    $35,906
#       Total Liabilities                                   $231,203
#       Commitments and contingencies
#       Stockholders’ equity:
#         Common Stock                                      $104,829
#         Retained Earnings                                 $203,482
#         Accumulated Other Comprehensive Income/Loss       $(5,616)
#         Total Stockholders' Equity                        $302,695       $102,976
#       Total Liabilities and Stockholders' Equity          $533,898
#                     Consolidated Statement of Income (Standardized)
#                 Three Months Ended (In millions, except per share data)
#
#                                                       Dec 31, 2024 (Q1)   Dec 31, 2024
#  ──────────────────────────────────────────────────────────────────────────────────────
#       Product and Service
#         Product and Service
#         Revenue                                                  69,632        135,217
#         Cost of Revenue                                         -21,799        -41,898
#         Gross Profit                                             47,833         93,319
#         Research and Development Expense                         -7,917        -15,461
#         Selling, General and Administrative Expense              -6,440        -12,157
#         Selling, General and Administrative Expense              -1,823         -3,496
#         Operating Income                                         31,653         62,205
#         Nonoperating Income/Expense                              -2,288         -2,571
#         Income Before Tax                                        29,365         59,634
#         Income Tax Expense                                       -5,257        -10,859
#         Net Income                                               24,108         48,775
#         Earnings per share:
#           Earnings Per Share                                          0              0
#           Earnings Per Share (Diluted)                                0              0
#         Weighted average shares outstanding:
#           Shares Outstanding                                      7,435          7,434
#           Shares Outstanding (Diluted)                            7,468          7,469

# %%
c = Company("AAPL")
f = c.latest("10-Q")
xbrl = XBRL.from_filing(f)
balance_sheet = xbrl.statements.balance_sheet()
balance_sheet
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                     Consolidated Balance Sheets (Standardized)
#            First Quarter Ended (In millions, except shares in thousands)
#
#                                                       Dec 28, 2024   Sep 28, 2024
#  ─────────────────────────────────────────────────────────────────────────────────
#     ASSETS:
#       Current assets:
#         Cash and Cash Equivalents                          $30,299        $29,943
#         Marketable Securities                              $23,476        $35,228
#         Accounts Receivable                                $29,639        $33,410
#         Vendor non-trade receivables                       $29,667        $32,833
#         Inventory                                           $6,911         $7,286
#         Other Assets                                       $13,248        $14,287
#         Total Current Assets                              $133,240       $152,987
#       Non-current assets:
#         Marketable securities                              $87,593        $91,479
#         Property, Plant and Equipment                      $46,069        $45,680
#         Other Assets                                       $77,183        $74,834
#         Total Current Assets                              $210,845       $211,993
#       Total Assets                                        $344,085       $364,980
#     LIABILITIES AND SHAREHOLDERS’ EQUITY:
#       Current liabilities:
#         Accounts Payable                                   $61,910        $68,960
#         Other Liabilities                                  $61,151        $78,304
#         Deferred Revenue                                    $8,461         $8,249
#         Commercial paper                                    $1,995         $9,967
#         Short-Term Debt                                    $10,848        $10,912
#         Total Current Liabilities                         $144,365       $176,392
#       Non-current liabilities:
#         Long-Term Debt                                     $83,956        $85,750
#         Other Liabilities                                  $49,006        $45,888
#         Total Current Liabilities                         $132,962       $131,638
#       Total Liabilities                                   $277,327       $308,030
#       Commitments and contingencies
#       Common Stock Shares Outstanding                      $15,041        $15,117
#       Common Stock Shares Issued                           $15,041        $15,117
#       Shareholders’ equity:
#         Common Stock                                       $84,768        $83,276
#         Retained Earnings                                $(11,221)      $(19,154)
#         Accumulated Other Comprehensive Income/Loss       $(6,789)       $(7,172)
#         Total Stockholders' Equity                         $66,758        $56,950
#       Total Liabilities and Stockholders' Equity          $344,085       $364,980

# %%
xbrl.statements.income_statement()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                         Consolidated Statement of Income (Standardized)
#                  Three Months Ended (In millions, except shares in thousands)
#
#                                                         Dec 28, 2024 (Q1)   Dec 30, 2023 (Q1)
#  ─────────────────────────────────────────────────────────────────────────────────────────────
#         Revenue                                               124,300,000         119,575,000
#         Cost of Revenue                                       -66,025,000         -64,720,000
#         Gross Profit                                           58,275,000          54,855,000
#         Operating Expenses
#           Research and Development Expense                      8,268,000           7,696,000
#           Selling, General and Administrative Expense           7,175,000           6,786,000
#           Operating Expenses                                  -15,443,000         -14,482,000
#         Operating Income                                       42,832,000          40,373,000
#         Nonoperating Income/Expense                              -248,000             -50,000
#         Income Before Tax                                      42,584,000          40,323,000
#         Income Tax Expense                                     -6,254,000          -6,407,000
#         Net Income                                             36,330,000          33,916,000
#         Earnings per share:
#           Earnings Per Share                                            0                   0
#           Earnings Per Share (Diluted)                                  0                   0
#         Shares used in computing earnings per share:
#           Shares Outstanding                                   15,081,724          15,509,763
#           Shares Outstanding (Diluted)                         15,150,865          15,576,641

# %%
(xbrl.query()
    .by_text("Revenue")
    .by_statement_type("IncomeStatement")
    .to_dataframe()
 )
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                                               concept      label  \
# 0   us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
# 1   us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
# 2   us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
# 3   us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
# 4   us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
# 5   us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
# 6   us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
# 7   us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
# 8   us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
# 9   us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
# 10  us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
# 11  us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
# 12  us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
# 13  us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
# 14  us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
# 15  us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
# 16  us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
# 17  us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
# 18  us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
# 19  us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
# 20  us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
# 21  us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
# 22  us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
# 23  us-gaap:RevenueFromContractWithCustomerExcludi...  Net sales
#
#            value  numeric_value period_start  period_end unit_ref decimals  \
# 0    97960000000   9.796000e+10   2024-09-29  2024-12-28      usd       -6
# 1    96458000000   9.645800e+10   2023-10-01  2023-12-30      usd       -6
# 2    26340000000   2.634000e+10   2024-09-29  2024-12-28      usd       -6
# 3    23117000000   2.311700e+10   2023-10-01  2023-12-30      usd       -6
# 4   124300000000   1.243000e+11   2024-09-29  2024-12-28      usd       -6
# 5   119575000000   1.195750e+11   2023-10-01  2023-12-30      usd       -6
# 6    69138000000   6.913800e+10   2024-09-29  2024-12-28      usd       -6
# 7    69702000000   6.970200e+10   2023-10-01  2023-12-30      usd       -6
# 8     8987000000   8.987000e+09   2024-09-29  2024-12-28      usd       -6
# 9     7780000000   7.780000e+09   2023-10-01  2023-12-30      usd       -6
# 10    8088000000   8.088000e+09   2024-09-29  2024-12-28      usd       -6
# 11    7023000000   7.023000e+09   2023-10-01  2023-12-30      usd       -6
# 12   11747000000   1.174700e+10   2024-09-29  2024-12-28      usd       -6
# 13   11953000000   1.195300e+10   2023-10-01  2023-12-30      usd       -6
# 14   52648000000   5.264800e+10   2024-09-29  2024-12-28      usd       -6
# 15   50430000000   5.043000e+10   2023-10-01  2023-12-30      usd       -6
# 16   33861000000   3.386100e+10   2024-09-29  2024-12-28      usd       -6
# 17   30397000000   3.039700e+10   2023-10-01  2023-12-30      usd       -6
# 18   18513000000   1.851300e+10   2024-09-29  2024-12-28      usd       -6
# 19   20819000000   2.081900e+10   2023-10-01  2023-12-30      usd       -6
# 20    8987000000   8.987000e+09   2024-09-29  2024-12-28      usd       -6
# 21    7767000000   7.767000e+09   2023-10-01  2023-12-30      usd       -6
# 22   10291000000   1.029100e+10   2024-09-29  2024-12-28      usd       -6
# 23   10162000000   1.016200e+10   2023-10-01  2023-12-30      usd       -6
#
#    footnotes            dim_srt_ProductOrServiceAxis   statement_type  \
# 0         []                   us-gaap:ProductMember  IncomeStatement
# 1         []                   us-gaap:ProductMember  IncomeStatement
# 2         []                   us-gaap:ServiceMember  IncomeStatement
# 3         []                   us-gaap:ServiceMember  IncomeStatement
# 4         []                                     NaN  IncomeStatement
# 5         []                                     NaN  IncomeStatement
# 6         []                       aapl:IPhoneMember  IncomeStatement
# 7         []                       aapl:IPhoneMember  IncomeStatement
# 8         []                          aapl:MacMember  IncomeStatement
# 9         []                          aapl:MacMember  IncomeStatement
# 10        []                         aapl:IPadMember  IncomeStatement
# 11        []                         aapl:IPadMember  IncomeStatement
# 12        []  aapl:WearablesHomeandAccessoriesMember  IncomeStatement
# 13        []  aapl:WearablesHomeandAccessoriesMember  IncomeStatement
# 14        []                                     NaN  IncomeStatement
# 15        []                                     NaN  IncomeStatement
# 16        []                                     NaN  IncomeStatement
# 17        []                                     NaN  IncomeStatement
# 18        []                                     NaN  IncomeStatement
# 19        []                                     NaN  IncomeStatement
# 20        []                                     NaN  IncomeStatement
# 21        []                                     NaN  IncomeStatement
# 22        []                                     NaN  IncomeStatement
# 23        []                                     NaN  IncomeStatement
#
#                                        statement_role  \
# 0   http://www.apple.com/role/CONDENSEDCONSOLIDATE...
# 1   http://www.apple.com/role/CONDENSEDCONSOLIDATE...
# 2   http://www.apple.com/role/CONDENSEDCONSOLIDATE...
# 3   http://www.apple.com/role/CONDENSEDCONSOLIDATE...
# 4   http://www.apple.com/role/CONDENSEDCONSOLIDATE...
# 5   http://www.apple.com/role/CONDENSEDCONSOLIDATE...
# 6   http://www.apple.com/role/CONDENSEDCONSOLIDATE...
# 7   http://www.apple.com/role/CONDENSEDCONSOLIDATE...
# 8   http://www.apple.com/role/CONDENSEDCONSOLIDATE...
# 9   http://www.apple.com/role/CONDENSEDCONSOLIDATE...
# 10  http://www.apple.com/role/CONDENSEDCONSOLIDATE...
# 11  http://www.apple.com/role/CONDENSEDCONSOLIDATE...
# 12  http://www.apple.com/role/CONDENSEDCONSOLIDATE...
# 13  http://www.apple.com/role/CONDENSEDCONSOLIDATE...
# 14  http://www.apple.com/role/CONDENSEDCONSOLIDATE...
# 15  http://www.apple.com/role/CONDENSEDCONSOLIDATE...
# 16  http://www.apple.com/role/CONDENSEDCONSOLIDATE...
# 17  http://www.apple.com/role/CONDENSEDCONSOLIDATE...
# 18  http://www.apple.com/role/CONDENSEDCONSOLIDATE...
# 19  http://www.apple.com/role/CONDENSEDCONSOLIDATE...
# 20  http://www.apple.com/role/CONDENSEDCONSOLIDATE...
# 21  http://www.apple.com/role/CONDENSEDCONSOLIDATE...
# 22  http://www.apple.com/role/CONDENSEDCONSOLIDATE...
# 23  http://www.apple.com/role/CONDENSEDCONSOLIDATE...
#
#    dim_us-gaap_StatementBusinessSegmentsAxis
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
# 5                                        NaN
# 6                                        NaN
# 7                                        NaN
# 8                                        NaN
# 9                                        NaN
# 10                                       NaN
# 11                                       NaN
# 12                                       NaN
# 13                                       NaN
# 14                aapl:AmericasSegmentMember
# 15                aapl:AmericasSegmentMember
# 16                  aapl:EuropeSegmentMember
# 17                  aapl:EuropeSegmentMember
# 18            aapl:GreaterChinaSegmentMember
# 19            aapl:GreaterChinaSegmentMember
# 20                   aapl:JapanSegmentMember
# 21                   aapl:JapanSegmentMember
# 22       aapl:RestOfAsiaPacificSegmentMember
# 23       aapl:RestOfAsiaPacificSegmentMember
